# %%
import pandas as pd
import numpy as np
shark_attacks_df = df = pd.read_excel("GSAF5.xls")
shark_attacks_df
# Out:
#              Date    Year          Type    Country            State  \
# 0     15 Oct-2023  2023.0    Unprovoked        USA           Hawaii
# 1     13 Oct-2023  2023.0  Questionable        USA       California
# 2     02 Oct-2023  2023.0    Unprovoked        USA           Hawaii
# 3     01 Oct-2023  2023.0    Unprovoked  AUSTRALIA  South Australia
# 4     01 Oct-2023  2023.0    Unprovoked        USA       California
# ...           ...     ...           ...        ...              ...
# 6926          NaN     NaN           NaN        NaN              NaN
# 6927          NaN     NaN           NaN        NaN              NaN
# 6928          NaN     NaN           NaN        NaN              NaN
# 6929          NaN     NaN           NaN        NaN              NaN
# 6930          NaN     NaN           NaN        NaN              NaN
#
#                                               Location  Activity  \
# 0                                   Hanalei Bay, Kauai   Surfing
# ...

# %%
#check the columns of the dataset
shark_attacks_df.nunique()
# Out:
# Date              5967
# Year               257
# Type                11
# Country            223
# State              892
# Location          4482
# Activity          1585
# Name              5658
# Sex                  8
# Age                243
# Injury            4064
# Unnamed: 11         12
# Time               408
# Species           1666
# Source            5271
# pdf               6789
# href formula      6785
# href              6776
# Case Number       6777
# Case Number.1     6775
# original order    6797
# Unnamed: 21          1
# Unnamed: 22          2
# dtype: int64

# %%
#dropping unnesseccary columns and assigning it to a new dataname
shark_attacks_dropped = shark_attacks_df.drop(["Name", "Sex", "Age", "Type", "Source", "pdf", "href formula","Unnamed: 11", "href", "Case Number", "Case Number.1", "original order","Unnamed: 21","Unnamed: 22"], axis=1)
shark_attacks_dropped
# Out:
#              Date    Year    Country            State  \
# 0     15 Oct-2023  2023.0        USA           Hawaii
# 1     13 Oct-2023  2023.0        USA       California
# 2     02 Oct-2023  2023.0        USA           Hawaii
# 3     01 Oct-2023  2023.0  AUSTRALIA  South Australia
# 4     01 Oct-2023  2023.0        USA       California
# ...           ...     ...        ...              ...
# 6926          NaN     NaN        NaN              NaN
# 6927          NaN     NaN        NaN              NaN
# 6928          NaN     NaN        NaN              NaN
# 6929          NaN     NaN        NaN              NaN
# 6930          NaN     NaN        NaN              NaN
#
#                                               Location  Activity  \
# 0                                   Hanalei Bay, Kauai   Surfing
# 1     Linda Mar, Pacific State Beach, San Mateo County   Surfing
# 2                                           Paia, Maui   Surfing
# ...

# %%
#checking the column names
shark_attacks_dropped.columns
# Out:
# Index(['Date', 'Year', 'Country', 'State', 'Location', 'Activity', 'Injury',
#        'Time', 'Species '],
#       dtype='object')

# %%
#lowercase the column names

new_shark_attacks_dropped = pd.Series(shark_attacks_dropped.columns).apply(lambda col:col.lower())
shark_attacks_dropped.columns = new_shark_attacks_dropped
shark_attacks_dropped
# Out:
#              date    year    country            state  \
# 0     15 Oct-2023  2023.0        USA           Hawaii
# 1     13 Oct-2023  2023.0        USA       California
# 2     02 Oct-2023  2023.0        USA           Hawaii
# 3     01 Oct-2023  2023.0  AUSTRALIA  South Australia
# 4     01 Oct-2023  2023.0        USA       California
# ...           ...     ...        ...              ...
# 6926          NaN     NaN        NaN              NaN
# 6927          NaN     NaN        NaN              NaN
# 6928          NaN     NaN        NaN              NaN
# 6929          NaN     NaN        NaN              NaN
# 6930          NaN     NaN        NaN              NaN
#
#                                               location  activity  \
# 0                                   Hanalei Bay, Kauai   Surfing
# 1     Linda Mar, Pacific State Beach, San Mateo County   Surfing
# 2                                           Paia, Maui   Surfing
# ...

# %%
#strip whitespaces from column names
shark_attacks_dropped.columns = shark_attacks_dropped.columns.str.strip()
shark_attacks_dropped.columns
# Out:
# Index(['date', 'year', 'country', 'state', 'location', 'activity', 'injury',
#        'time', 'species'],
#       dtype='object')

# %%
# replace emtpy cells with NaN
#df = df.replace("", np.nan, regex=True)

# %%
#customer_data[“customer lifetime value”] = customer_data[‘customer lifetime value’].replace(‘%’,‘’).astype(float)
#customer_data[“customer lifetime value”].value_counts()

shark_attacks_dropped["year"] = shark_attacks_dropped["year"].replace(".0", "")
shark_attacks_dropped
# Out:
#              date    year    country            state  \
# 0     15 Oct-2023  2023.0        USA           Hawaii
# 1     13 Oct-2023  2023.0        USA       California
# 2     02 Oct-2023  2023.0        USA           Hawaii
# 3     01 Oct-2023  2023.0  AUSTRALIA  South Australia
# 4     01 Oct-2023  2023.0        USA       California
# ...           ...     ...        ...              ...
# 6926          NaN     NaN        NaN              NaN
# 6927          NaN     NaN        NaN              NaN
# 6928          NaN     NaN        NaN              NaN
# 6929          NaN     NaN        NaN              NaN
# 6930          NaN     NaN        NaN              NaN
#
#                                               location  activity  \
# 0                                   Hanalei Bay, Kauai   Surfing
# 1     Linda Mar, Pacific State Beach, San Mateo County   Surfing
# 2                                           Paia, Maui   Surfing
# ...

# %%
#check the data type of the year column
data_type = shark_attacks_dropped["year"].dtype
print(data_type)
# Out:
# float64

# %%
shark_attacks_dropped.isna().any()
# Out:
# date        True
# year        True
# country     True
# state       True
# location    True
# activity    True
# injury      True
# time        True
# species     True
# dtype: bool

# %%
shark_attacks_dropped.isna().sum()
# Out:
# date          25
# year          27
# country       75
# state        506
# location     589
# activity     609
# injury        60
# time        3543
# species     3145
# dtype: int64

# %%
shark_attacks_dropped.tail(150)
# Out:
#                date  year    country       state            location  \
# 6781  Ca. 1010  BC    0.0      JAPAN         NaN  Archeological site
# 6782     Ca 4000 BC   0.0       PERU      Paloma  Archeological site
# 6783  Prior to 1988   0.0     BELIZE         NaN                 NaN
# 6784     After 2013   0.0  AUSTRALIA  Queensland          Otter Reef
# 6785    Before 1824   0.0  AUSTRALIA  Queensland            Newstead
# ...             ...   ...        ...         ...                 ...
# 6926            NaN   NaN        NaN         NaN                 NaN
# 6927            NaN   NaN        NaN         NaN                 NaN
# 6928            NaN   NaN        NaN         NaN                 NaN
# 6929            NaN   NaN        NaN         NaN                 NaN
# 6930            NaN   NaN        NaN         NaN                 NaN
#
#            activity                           injury time           species
# ...

# %%
#getting rid of empty rows
shark_attacks_dropped.dropna(thresh=5)
# Out:
#              date    year             country              state  \
# 0     15 Oct-2023  2023.0                 USA             Hawaii
# 1     13 Oct-2023  2023.0                 USA         California
# 2     02 Oct-2023  2023.0                 USA             Hawaii
# 3     01 Oct-2023  2023.0           AUSTRALIA    South Australia
# 4     01 Oct-2023  2023.0                 USA         California
# ...           ...     ...                 ...                ...
# 6901  Before 1903     0.0           AUSTRALIA  Western Australia
# 6902  Before 1903     0.0           AUSTRALIA  Western Australia
# 6903    1900-1905     0.0                 USA     North Carolina
# 6904    1883-1889     0.0              PANAMA                NaN
# 6905    1845-1853     0.0  CEYLON (SRI LANKA)   Eastern Province
#
#                                               location      activity  \
# 0                                   Hanalei Bay, Kauai       Surfing
# ...

# %%
year = shark_attacks_dropped['year'].unique()
year
# Out:
# array([2023., 2022., 2021., 2020., 2019., 2018., 2017.,   nan, 2016.,
#        2015., 2014., 2013., 2012., 2011., 2010., 2009., 2008., 2007.,
#        2006., 2005., 2004., 2003., 2002., 2001., 2000., 1999., 1998.,
#        1997., 1996., 1995., 1984., 1994., 1993., 1992., 1991., 1990.,
#        1989., 1969., 1988., 1987., 1986., 1985., 1983., 1982., 1981.,
#        1980., 1979., 1978., 1977., 1976., 1975., 1974., 1973., 1972.,
#        1971., 1970., 1968., 1967., 1966., 1965., 1964., 1963., 1962.,
#        1961., 1960., 1959., 1958., 1957., 1956., 1955., 1954., 1953.,
#        1952., 1951., 1950., 1949., 1948., 1848., 1947., 1946., 1945.,
#        1944., 1943., 1942., 1941., 1940., 1939., 1938., 1937., 1936.,
#        1935., 1934., 1933., 1932., 1931., 1930., 1929., 1928., 1927.,
#        1926., 1925., 1924., 1923., 1922., 1921., 1920., 1919., 1918.,
#        1917., 1916., 1915., 1914., 1913., 1912., 1911., 1910., 1909.,
# ...

# %%
target_value ="   nan"  # Change this to the value you want to search for

# Using the loc[] attribute to find row indices
rows_with_value = shark_attacks_dropped[shark_attacks_dropped["year"]==target_value]
rows_with_value
# Out:
# Empty DataFrame
# Columns: [date, year, country, state, location, activity, injury, time, species]
# Index: []

# %% [markdown]
# # Installing Spotipy

# %%
##!conda install -c conda-forge spotipy

# %% [markdown]
# ## Loading credentials from the config file

# %%
import config

# %% [markdown]
# ## Starting with Spotify API

# %%
import spotipy
import pandas as pd
import json
from spotipy.oauth2 import SpotifyClientCredentials


#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))



results = sp.search(q="daddy cool",limit=5,market="GB")
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=daddy+cool&type=track&market=GB&offset=0&limit=5',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#        'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#        'id': '54R6Y0I7jGUCveDTtI21nb',
#        'name': 'Boney M.',
#        'type': 'artist',
#        'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1KQUrny9y5zGpktF6hAGd4'},
#      'href': 'https://api.spotify.com/v1/albums/1KQUrny9y5zGpktF6hAGd4',
#      'id': '1KQUrny9y5zGpktF6hAGd4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273dafd1cd6e9537ec8463ea691',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02dafd1cd6e9537ec8463ea691',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851dafd1cd6e9537ec8463ea691',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Take The Heat Off Me',
#      'release_date': '1976',
#      'release_date_precision': 'year',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:1KQUrny9y5zGpktF6hAGd4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#       'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#       'id': '54R6Y0I7jGUCveDTtI21nb',
#       'name': 'Boney M.',
#       'type': 'artist',
#       'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#     'disc_number': 1,
#     'duration_ms': 208600,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEC737600002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3WMbD1OyfKuwWDWMNbPQ4g'},
#     'href': 'https://api.spotify.com/v1/tracks/3WMbD1OyfKuwWDWMNbPQ4g',
#     'id': '3WMbD1OyfKuwWDWMNbPQ4g',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Daddy Cool',
#     'popularity': 75,
#     'preview_url': 'https://p.scdn.co/mp3-preview/03e2b60a6a5c101dc0d41866f2e079d8de4a663b?cid=d93283ae0ac74ebc9d1ecc472254bada',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3WMbD1OyfKuwWDWMNbPQ4g'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12A83CWwFiyXy90ScLWPIe'},
#        'href': 'https://api.spotify.com/v1/artists/12A83CWwFiyXy90ScLWPIe',
#        'id': '12A83CWwFiyXy90ScLWPIe',
#        'name': 'LIZOT',
#        'type': 'artist',
#        'uri': 'spotify:artist:12A83CWwFiyXy90ScLWPIe'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#        'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#        'id': '54R6Y0I7jGUCveDTtI21nb',
#        'name': 'Boney M.',
#        'type': 'artist',
#        'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7fXtm0TpLRIJhxobKDjxRp'},
#      'href': 'https://api.spotify.com/v1/albums/7fXtm0TpLRIJhxobKDjxRp',
#      'id': '7fXtm0TpLRIJhxobKDjxRp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273da8ce498bc7d441e6d841d25',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02da8ce498bc7d441e6d841d25',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851da8ce498bc7d441e6d841d25',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Daddy Cool',
#      'release_date': '2021-12-03',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7fXtm0TpLRIJhxobKDjxRp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12A83CWwFiyXy90ScLWPIe'},
#       'href': 'https://api.spotify.com/v1/artists/12A83CWwFiyXy90ScLWPIe',
#       'id': '12A83CWwFiyXy90ScLWPIe',
#       'name': 'LIZOT',
#       'type': 'artist',
#       'uri': 'spotify:artist:12A83CWwFiyXy90ScLWPIe'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#       'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#       'id': '54R6Y0I7jGUCveDTtI21nb',
#       'name': 'Boney M.',
#       'type': 'artist',
#       'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#     'disc_number': 1,
#     'duration_ms': 154858,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEE862102870'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/50rcUhHimavzT1qq6QrgMG'},
#     'href': 'https://api.spotify.com/v1/tracks/50rcUhHimavzT1qq6QrgMG',
#     'id': '50rcUhHimavzT1qq6QrgMG',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Daddy Cool',
#     'popularity': 58,
#     'preview_url': 'https://p.scdn.co/mp3-preview/857d68f8f69125e431cea3e5e89e653440600762?cid=d93283ae0ac74ebc9d1ecc472254bada',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:50rcUhHimavzT1qq6QrgMG'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#        'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#        'id': '54R6Y0I7jGUCveDTtI21nb',
#        'name': 'Boney M.',
#        'type': 'artist',
#        'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7sP5qOivaWh1y7UDiu0q1c'},
#      'href': 'https://api.spotify.com/v1/albums/7sP5qOivaWh1y7UDiu0q1c',
#      'id': '7sP5qOivaWh1y7UDiu0q1c',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27317f1f3806475c7c8efb04dbc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0217f1f3806475c7c8efb04dbc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485117f1f3806475c7c8efb04dbc',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'The Greatest Hits',
#      'release_date': '2001-11-29',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:7sP5qOivaWh1y7UDiu0q1c'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#       'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#       'id': '54R6Y0I7jGUCveDTtI21nb',
#       'name': 'Boney M.',
#       'type': 'artist',
#       'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#     'disc_number': 1,
#     'duration_ms': 318066,
#     'explicit': False,
#     'external_ids': {'isrc': 'DED160100013'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6AJICOpiJjrI8NKKsNezTk'},
#     'href': 'https://api.spotify.com/v1/tracks/6AJICOpiJjrI8NKKsNezTk',
#     'id': '6AJICOpiJjrI8NKKsNezTk',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Daddy Cool - Remix 2001',
#     'popularity': 30,
#     'preview_url': 'https://p.scdn.co/mp3-preview/09b860a80e1db6d873027558f1593ad72180d43b?cid=d93283ae0ac74ebc9d1ecc472254bada',
#     'track_number': 17,
#     'type': 'track',
#     'uri': 'spotify:track:6AJICOpiJjrI8NKKsNezTk'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#        'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#        'id': '6RZUqkomCmb8zCRqc9eznB',
#        'name': 'Placebo',
#        'type': 'artist',
#        'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7kTsa1wUFrahJJf1cJEOpZ'},
#      'href': 'https://api.spotify.com/v1/albums/7kTsa1wUFrahJJf1cJEOpZ',
#      'id': '7kTsa1wUFrahJJf1cJEOpZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27362c995dbce6d7ffa4c097475',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0262c995dbce6d7ffa4c097475',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485162c995dbce6d7ffa4c097475',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Covers',
#      'release_date': '2003-03-24',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:7kTsa1wUFrahJJf1cJEOpZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#       'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#       'id': '6RZUqkomCmb8zCRqc9eznB',
#       'name': 'Placebo',
#       'type': 'artist',
#       'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#     'disc_number': 1,
#     'duration_ms': 201706,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAAA0201215'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6blKbRwYDoXl5fFvQY2U75'},
#     'href': 'https://api.spotify.com/v1/tracks/6blKbRwYDoXl5fFvQY2U75',
#     'id': '6blKbRwYDoXl5fFvQY2U75',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Daddy Cool',
#     'popularity': 46,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4af3ad78f847b23200036e9cee4d5b06868aea6b?cid=d93283ae0ac74ebc9d1ecc472254bada',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:6blKbRwYDoXl5fFvQY2U75'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#        'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#        'id': '54R6Y0I7jGUCveDTtI21nb',
#        'name': 'Boney M.',
#        'type': 'artist',
#        'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4PSRe9AYegkUyPHzbfpdrK'},
#      'href': 'https://api.spotify.com/v1/albums/4PSRe9AYegkUyPHzbfpdrK',
#      'id': '4PSRe9AYegkUyPHzbfpdrK',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27330831f10b40dde1d0acefa8c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0230831f10b40dde1d0acefa8c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485130831f10b40dde1d0acefa8c',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Diamonds (40th Anniversary Edition)',
#      'release_date': '2015-03-27',
#      'release_date_precision': 'day',
#      'total_tracks': 53,
#      'type': 'album',
#      'uri': 'spotify:album:4PSRe9AYegkUyPHzbfpdrK'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#       'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#       'id': '54R6Y0I7jGUCveDTtI21nb',
#       'name': 'Boney M.',
#       'type': 'artist',
#       'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6spxYGp8SA2xvJOQ0VjFUV'},
#       'href': 'https://api.spotify.com/v1/artists/6spxYGp8SA2xvJOQ0VjFUV',
#       'id': '6spxYGp8SA2xvJOQ0VjFUV',
#       'name': 'Nick Raider (Christian Geller)',
#       'type': 'artist',
#       'uri': 'spotify:artist:6spxYGp8SA2xvJOQ0VjFUV'}],
#     'disc_number': 3,
#     'duration_ms': 208626,
#     'explicit': False,
#     'external_ids': {'isrc': 'DED161500020'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2TVXrjsGdTCUNqF7ns2I15'},
#     'href': 'https://api.spotify.com/v1/tracks/2TVXrjsGdTCUNqF7ns2I15',
#     'id': '2TVXrjsGdTCUNqF7ns2I15',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Daddy Cool - Nick Raider Radio Mix',
#     'popularity': 51,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f41fb9de41c55136720dbfea82cd5f130611055b?cid=d93283ae0ac74ebc9d1ecc472254bada',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:2TVXrjsGdTCUNqF7ns2I15'}],
#   'limit': 5,
#   'next': 'https://api.spotify.com/v1/search?query=daddy+cool&type=track&market=GB&offset=5&limit=5',
#   'offset': 0,
#   'previous': None,
#   'total': 823}}

# %%
import pprint

# %%
pprint.pprint(results["tracks"]["items"][0]["album"]["artists"][0]["name"])
# Out:
# 'Boney M.'

# %%
results['tracks']
# Out:
# {'href': 'https://api.spotify.com/v1/search?query=daddy+cool&type=track&market=GB&offset=0&limit=5',
#  'items': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#       'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#       'id': '54R6Y0I7jGUCveDTtI21nb',
#       'name': 'Boney M.',
#       'type': 'artist',
#       'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1KQUrny9y5zGpktF6hAGd4'},
#     'href': 'https://api.spotify.com/v1/albums/1KQUrny9y5zGpktF6hAGd4',
#     'id': '1KQUrny9y5zGpktF6hAGd4',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273dafd1cd6e9537ec8463ea691',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02dafd1cd6e9537ec8463ea691',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851dafd1cd6e9537ec8463ea691',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Take The Heat Off Me',
#     'release_date': '1976',
#     'release_date_precision': 'year',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:1KQUrny9y5zGpktF6hAGd4'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#      'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#      'id': '54R6Y0I7jGUCveDTtI21nb',
#      'name': 'Boney M.',
#      'type': 'artist',
#      'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#    'disc_number': 1,
#    'duration_ms': 208600,
#    'explicit': False,
#    'external_ids': {'isrc': 'DEC737600002'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3WMbD1OyfKuwWDWMNbPQ4g'},
#    'href': 'https://api.spotify.com/v1/tracks/3WMbD1OyfKuwWDWMNbPQ4g',
#    'id': '3WMbD1OyfKuwWDWMNbPQ4g',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Daddy Cool',
#    'popularity': 75,
#    'preview_url': 'https://p.scdn.co/mp3-preview/03e2b60a6a5c101dc0d41866f2e079d8de4a663b?cid=bf09462e42d046dbae74fb8d2b745b9b',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3WMbD1OyfKuwWDWMNbPQ4g'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12A83CWwFiyXy90ScLWPIe'},
#       'href': 'https://api.spotify.com/v1/artists/12A83CWwFiyXy90ScLWPIe',
#       'id': '12A83CWwFiyXy90ScLWPIe',
#       'name': 'LIZOT',
#       'type': 'artist',
#       'uri': 'spotify:artist:12A83CWwFiyXy90ScLWPIe'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#       'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#       'id': '54R6Y0I7jGUCveDTtI21nb',
#       'name': 'Boney M.',
#       'type': 'artist',
#       'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7fXtm0TpLRIJhxobKDjxRp'},
#     'href': 'https://api.spotify.com/v1/albums/7fXtm0TpLRIJhxobKDjxRp',
#     'id': '7fXtm0TpLRIJhxobKDjxRp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273da8ce498bc7d441e6d841d25',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02da8ce498bc7d441e6d841d25',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851da8ce498bc7d441e6d841d25',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Daddy Cool',
#     'release_date': '2021-12-03',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:7fXtm0TpLRIJhxobKDjxRp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12A83CWwFiyXy90ScLWPIe'},
#      'href': 'https://api.spotify.com/v1/artists/12A83CWwFiyXy90ScLWPIe',
#      'id': '12A83CWwFiyXy90ScLWPIe',
#      'name': 'LIZOT',
#      'type': 'artist',
#      'uri': 'spotify:artist:12A83CWwFiyXy90ScLWPIe'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#      'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#      'id': '54R6Y0I7jGUCveDTtI21nb',
#      'name': 'Boney M.',
#      'type': 'artist',
#      'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#    'disc_number': 1,
#    'duration_ms': 154858,
#    'explicit': False,
#    'external_ids': {'isrc': 'DEE862102870'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/50rcUhHimavzT1qq6QrgMG'},
#    'href': 'https://api.spotify.com/v1/tracks/50rcUhHimavzT1qq6QrgMG',
#    'id': '50rcUhHimavzT1qq6QrgMG',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Daddy Cool',
#    'popularity': 58,
#    'preview_url': 'https://p.scdn.co/mp3-preview/857d68f8f69125e431cea3e5e89e653440600762?cid=bf09462e42d046dbae74fb8d2b745b9b',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:50rcUhHimavzT1qq6QrgMG'},
#   {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#       'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#       'id': '54R6Y0I7jGUCveDTtI21nb',
#       'name': 'Boney M.',
#       'type': 'artist',
#       'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7sP5qOivaWh1y7UDiu0q1c'},
#     'href': 'https://api.spotify.com/v1/albums/7sP5qOivaWh1y7UDiu0q1c',
#     'id': '7sP5qOivaWh1y7UDiu0q1c',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27317f1f3806475c7c8efb04dbc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0217f1f3806475c7c8efb04dbc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485117f1f3806475c7c8efb04dbc',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'The Greatest Hits',
#     'release_date': '2001-11-29',
#     'release_date_precision': 'day',
#     'total_tracks': 18,
#     'type': 'album',
#     'uri': 'spotify:album:7sP5qOivaWh1y7UDiu0q1c'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#      'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#      'id': '54R6Y0I7jGUCveDTtI21nb',
#      'name': 'Boney M.',
#      'type': 'artist',
#      'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#    'disc_number': 1,
#    'duration_ms': 318066,
#    'explicit': False,
#    'external_ids': {'isrc': 'DED160100013'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6AJICOpiJjrI8NKKsNezTk'},
#    'href': 'https://api.spotify.com/v1/tracks/6AJICOpiJjrI8NKKsNezTk',
#    'id': '6AJICOpiJjrI8NKKsNezTk',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Daddy Cool - Remix 2001',
#    'popularity': 30,
#    'preview_url': 'https://p.scdn.co/mp3-preview/09b860a80e1db6d873027558f1593ad72180d43b?cid=bf09462e42d046dbae74fb8d2b745b9b',
#    'track_number': 17,
#    'type': 'track',
#    'uri': 'spotify:track:6AJICOpiJjrI8NKKsNezTk'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#       'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#       'id': '6RZUqkomCmb8zCRqc9eznB',
#       'name': 'Placebo',
#       'type': 'artist',
#       'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7kTsa1wUFrahJJf1cJEOpZ'},
#     'href': 'https://api.spotify.com/v1/albums/7kTsa1wUFrahJJf1cJEOpZ',
#     'id': '7kTsa1wUFrahJJf1cJEOpZ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27362c995dbce6d7ffa4c097475',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0262c995dbce6d7ffa4c097475',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485162c995dbce6d7ffa4c097475',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Covers',
#     'release_date': '2003-03-24',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:7kTsa1wUFrahJJf1cJEOpZ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#      'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#      'id': '6RZUqkomCmb8zCRqc9eznB',
#      'name': 'Placebo',
#      'type': 'artist',
#      'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#    'disc_number': 1,
#    'duration_ms': 201706,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAAA0201215'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6blKbRwYDoXl5fFvQY2U75'},
#    'href': 'https://api.spotify.com/v1/tracks/6blKbRwYDoXl5fFvQY2U75',
#    'id': '6blKbRwYDoXl5fFvQY2U75',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Daddy Cool',
#    'popularity': 46,
#    'preview_url': 'https://p.scdn.co/mp3-preview/4af3ad78f847b23200036e9cee4d5b06868aea6b?cid=bf09462e42d046dbae74fb8d2b745b9b',
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:6blKbRwYDoXl5fFvQY2U75'},
#   {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#       'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#       'id': '54R6Y0I7jGUCveDTtI21nb',
#       'name': 'Boney M.',
#       'type': 'artist',
#       'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4PSRe9AYegkUyPHzbfpdrK'},
#     'href': 'https://api.spotify.com/v1/albums/4PSRe9AYegkUyPHzbfpdrK',
#     'id': '4PSRe9AYegkUyPHzbfpdrK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27330831f10b40dde1d0acefa8c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0230831f10b40dde1d0acefa8c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485130831f10b40dde1d0acefa8c',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Diamonds (40th Anniversary Edition)',
#     'release_date': '2015-03-27',
#     'release_date_precision': 'day',
#     'total_tracks': 53,
#     'type': 'album',
#     'uri': 'spotify:album:4PSRe9AYegkUyPHzbfpdrK'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#      'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#      'id': '54R6Y0I7jGUCveDTtI21nb',
#      'name': 'Boney M.',
#      'type': 'artist',
#      'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6spxYGp8SA2xvJOQ0VjFUV'},
#      'href': 'https://api.spotify.com/v1/artists/6spxYGp8SA2xvJOQ0VjFUV',
#      'id': '6spxYGp8SA2xvJOQ0VjFUV',
#      'name': 'Nick Raider (Christian Geller)',
#      'type': 'artist',
#      'uri': 'spotify:artist:6spxYGp8SA2xvJOQ0VjFUV'}],
#    'disc_number': 3,
#    'duration_ms': 208626,
#    'explicit': False,
#    'external_ids': {'isrc': 'DED161500020'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2TVXrjsGdTCUNqF7ns2I15'},
#    'href': 'https://api.spotify.com/v1/tracks/2TVXrjsGdTCUNqF7ns2I15',
#    'id': '2TVXrjsGdTCUNqF7ns2I15',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Daddy Cool - Nick Raider Radio Mix',
#    'popularity': 51,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f41fb9de41c55136720dbfea82cd5f130611055b?cid=bf09462e42d046dbae74fb8d2b745b9b',
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:2TVXrjsGdTCUNqF7ns2I15'}],
#  'limit': 5,
#  'next': 'https://api.spotify.com/v1/search?query=daddy+cool&type=track&market=GB&offset=5&limit=5',
#  'offset': 0,
#  'previous': None,
#  'total': 823}

# %% [markdown]
# # Understanding the json

# %%
print("The json file has the following keys: ",list(results.keys())) # We can see that we only have tracks
print("The 'tracks' key has the following child keys: ",list(results["tracks"].keys())) # Let's check the values
print("The query we made is: ",results["tracks"]["href"]) # Query we have searched 
print("The song's info is contained in: ",results["tracks"]["items"]) #items (actual tracks)
print("The limit of the query we've made is: ",results["tracks"]["limit"]) #Limit we have chosen
print("The next page if any: ",results["tracks"]["next"]) #link to the next page (next 50 tracks)
print("The starting webpage: ",results["tracks"]["offset"]) # Actual offset (starting point)
print("Starting webpage: ",results["tracks"]["previous"]) #Previous search
print("Total number of results: ",results["tracks"]["total"]) # Number of matches
# Out:
# The json file has the following keys:  ['tracks']
# The 'tracks' key has the following child keys:  ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# The query we made is:  https://api.spotify.com/v1/search?query=daddy+cool&type=track&market=GB&offset=0&limit=5
# The song's info is contained in:  [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'}, 'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb', 'id': '54R6Y0I7jGUCveDTtI21nb', 'name': 'Boney M.', 'type': 'artist', 'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/1KQUrny9y5zGpktF6hAGd4'}, 'href': 'https://api.spotify.com/v1/albums/1KQUrny9y5zGpktF6hAGd4', 'id': '1KQUrny9y5zGpktF6hAGd4', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273dafd1cd6e9537ec8463ea691', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02dafd1cd6e9537ec8463ea691', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851dafd1cd6e9537ec8463ea691', 'width': 64}], 'is_playable': True, 'name': 'Take The Heat Off Me', 'release_date': '1976', 'release_date_precision': 'year', 'total_tracks': 10, 'type': 'album', 'uri': 'spotify:album:1KQUrny9y5zGpktF6hAGd4'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'}, 'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb', 'id': '54R6Y0I7jGUCveDTtI21nb', 'name': 'Boney M.', 'type': 'artist', 'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}], 'disc_number': 1, 'duration_ms': 208600, 'explicit': False, 'external_ids': {'isrc': 'DEC737600002'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/3WMbD1OyfKuwWDWMNbPQ4g'}, 'href': 'https://api.spotify.com/v1/tracks/3WMbD1OyfKuwWDWMNbPQ4g', 'id': '3WMbD1OyfKuwWDWMNbPQ4g', 'is_local': False, 'is_playable': True, 'name': 'Daddy Cool', 'popularity': 75, 'preview_url': 'https://p.scdn.co/mp3-preview/03e2b60a6a5c101dc0d41866f2e079d8de4a663b?cid=bf09462e42d046dbae74fb8d2b745b9b', 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:3WMbD1OyfKuwWDWMNbPQ4g'}, {'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12A83CWwFiyXy90ScLWPIe'}, 'href': 'https://api.spotify.com/v1/artists/12A83CWwFiyXy90ScLWPIe', 'id': '12A83CWwFiyXy90ScLWPIe', 'name': 'LIZOT', 'type': 'artist', 'uri': 'spotify:artist:12A83CWwFiyXy90ScLWPIe'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'}, 'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb', 'id': '54R6Y0I7jGUCveDTtI21nb', 'name': 'Boney M.', 'type': 'artist', 'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/7fXtm0TpLRIJhxobKDjxRp'}, 'href': 'https://api.spotify.com/v1/albums/7fXtm0TpLRIJhxobKDjxRp', 'id': '7fXtm0TpLRIJhxobKDjxRp', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273da8ce498bc7d441e6d841d25', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02da8ce498bc7d441e6d841d25', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851da8ce498bc7d441e6d841d25', 'width': 64}], 'is_playable': True, 'name': 'Daddy Cool', 'release_date': '2021-12-03', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:7fXtm0TpLRIJhxobKDjxRp'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12A83CWwFiyXy90ScLWPIe'}, 'href': 'https://api.spotify.com/v1/artists/12A83CWwFiyXy90ScLWPIe', 'id': '12A83CWwFiyXy90ScLWPIe', 'name': 'LIZOT', 'type': 'artist', 'uri': 'spotify:artist:12A83CWwFiyXy90ScLWPIe'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'}, 'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb', 'id': '54R6Y0I7jGUCveDTtI21nb', 'name': 'Boney M.', 'type': 'artist', 'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}], 'disc_number': 1, 'duration_ms': 154858, 'explicit': False, 'external_ids': {'isrc': 'DEE862102870'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/50rcUhHimavzT1qq6QrgMG'}, 'hre ...
# The limit of the query we've made is:  5
# The next page if any:  https://api.spotify.com/v1/search?query=daddy+cool&type=track&market=GB&offset=5&limit=5
# The starting webpage:  0
# Starting webpage:  None
# Total number of results:  823

# %% [markdown]
# ## Other Info

# %%
results["tracks"]["items"][0]["artists"] # Track artists
results["tracks"]["items"][0]["id"] # Track ID
results["tracks"]["items"][0]["name"] # Track name
results["tracks"]["items"][0]["popularity"] # Popularity index
results["tracks"]["items"][0]["uri"] # Basically ID
# Out:
# 'spotify:track:3WMbD1OyfKuwWDWMNbPQ4g'

# %%
len(results['tracks']["items"])
# Out:
# 5

# %% [markdown]
# ## Getting the track_id

# %%
track_id=results["tracks"]["items"][0]["id"]
track_id
# Out:
# '3WMbD1OyfKuwWDWMNbPQ4g'

# %%
for item in results['tracks']['items']:
    print("The name of song is: '{}' and the id is: {}".format(item['name'],item["id"]))
# Out:
# The name of song is: 'Daddy Cool' and the id is: 3WMbD1OyfKuwWDWMNbPQ4g
# The name of song is: 'Daddy Cool' and the id is: 50rcUhHimavzT1qq6QrgMG
# The name of song is: 'Daddy Cool - Remix 2001' and the id is: 6AJICOpiJjrI8NKKsNezTk
# The name of song is: 'Daddy Cool' and the id is: 6blKbRwYDoXl5fFvQY2U75
# The name of song is: 'Daddy Cool - Nick Raider Radio Mix' and the id is: 2TVXrjsGdTCUNqF7ns2I15

# %% [markdown]
# ## Embeded track player

# %%
from IPython.display import IFrame

track_id = '3WMbD1OyfKuwWDWMNbPQ4g'
#track_id= 'spotify:track:3hgl7EQwTutSm6PESsB7gZ'
IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/3WMbD1OyfKuwWDWMNbPQ4g?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
def play_song(track_id):
    return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %%
play_song('3WMbD1OyfKuwWDWMNbPQ4g')
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/3WMbD1OyfKuwWDWMNbPQ4g?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Getting the Audio features of a song

# %%
results["tracks"]["items"][0]["id"]
# Out:
# '3WMbD1OyfKuwWDWMNbPQ4g'

# %%
sp.audio_features(results["tracks"]["items"][0]["id"] )[0]
# Out:
# Max Retries reached
# ---------------------------------------------------------------------------
# MaxRetryError                             Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:889, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     888     log.debug("Retry: %s", url)
# --> 889     return self.urlopen(
#     890         method,
#     891         url,
#     892         body,
#     893         headers,
#     894         retries=retries,
#     895         redirect=redirect,
#     896         assert_same_host=assert_same_host,
#     897         timeout=timeout,
#     898         pool_timeout=pool_timeout,
#     899         release_conn=release_conn,
#     900         chunked=chunked,
#     901         body_pos=body_pos,
#     902         **response_kw
#     903     )
#     905 return response
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:889, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     888     log.debug("Retry: %s", url)
# --> 889     return self.urlopen(
#     890         method,
#     891         url,
#     892         body,
#     893         headers,
#     894         retries=retries,
#     895         redirect=redirect,
#     896         assert_same_host=assert_same_host,
#     897         timeout=timeout,
#     898         pool_timeout=pool_timeout,
#     899         release_conn=release_conn,
#     900         chunked=chunked,
#     901         body_pos=body_pos,
#     902         **response_kw
#     903     )
#     905 return response
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:889, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     888     log.debug("Retry: %s", url)
# --> 889     return self.urlopen(
#     890         method,
#     891         url,
#     892         body,
#     893         headers,
#     894         retries=retries,
#     895         redirect=redirect,
#     896         assert_same_host=assert_same_host,
#     897         timeout=timeout,
#     898         pool_timeout=pool_timeout,
#     899         release_conn=release_conn,
#     900         chunked=chunked,
#     901         body_pos=body_pos,
#     902         **response_kw
#     903     )
#     905 return response
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:879, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     878 try:
# --> 879     retries = retries.increment(method, url, response=response, _pool=self)
#     880 except MaxRetryError:
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/audio-features/?ids=3WMbD1OyfKuwWDWMNbPQ4g (Caused by ResponseError('too many 429 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# RetryError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\spotipy\client.py:266, in Spotify._internal_call(self, method, url, payload, params)
#     265 try:
# --> 266     response = self._session.request(
#     267         method, url, headers=headers, proxies=self.proxies,
#     268         timeout=self.requests_timeout, **args
#     269     )
#     271     response.raise_for_status()
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:510, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     509 if isinstance(e.reason, ResponseError):
# --> 510     raise RetryError(e, request=request)
#     512 if isinstance(e.reason, _ProxyError):
#
# RetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/audio-features/?ids=3WMbD1OyfKuwWDWMNbPQ4g (Caused by ResponseError('too many 429 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 sp.audio_features(results["tracks"]["items"][0]["id"] )[0]
#
# File ~\anaconda3\Lib\site-packages\spotipy\client.py:1734, in Spotify.audio_features(self, tracks)
#    1732 if isinstance(tracks, str):
#    1733     trackid = self._get_id("track", tracks)
# -> 1734     results = self._get("audio-features/?ids=" + trackid)
#    1735 else:
#    1736     tlist = [self._get_id("track", t) for t in tracks]
#
# File ~\anaconda3\Lib\site-packages\spotipy\client.py:323, in Spotify._get(self, url, args, payload, **kwargs)
#     320 if args:
#     321     kwargs.update(args)
# --> 323 return self._internal_call("GET", url, payload, kwargs)
#
# File ~\anaconda3\Lib\site-packages\spotipy\client.py:307, in Spotify._internal_call(self, method, url, payload, params)
#     305     except (IndexError, AttributeError):
#     306         reason = None
# --> 307     raise SpotifyException(
#     308         429,
#     309         -1,
#     310         "%s:\n %s" % (request.path_url, "Max Retries"),
#     311         reason=reason
#     312     )
#     313 except ValueError:
#     314     results = None
#
# SpotifyException: http status: 429, code:-1 - /v1/audio-features/?ids=3WMbD1OyfKuwWDWMNbPQ4g:
#  Max Retries, reason: too many 429 error responses

# %%
## example of bethoven song
sp.audio_features('2TVxnKdb3tqe1nhQWwwZCO')

# %%
play_song('2TVxnKdb3tqe1nhQWwwZCO')

# %% [markdown]
# ## Building a Data frame of audio features

# %%
sp.audio_features(results["tracks"]["items"][0]["uri"])

# %%
#my_dict = sp.audio_features(song["tracks"]["items"][0]["uri"])[0] # you can provide a list of uri's

list_of_songs=[]
for index in range(0,len(results["tracks"]["items"])):
    list_of_songs.append(sp.audio_features(results["tracks"]["items"][index]["uri"])[0])
df=pd.DataFrame(list_of_songs)    
df=df[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df

# %% [markdown]
# ## Searching a playlist

# %%
playlist = sp.user_playlist_tracks("spotify", "37i9dQZF1DZ06evO2A96G4",market="GB")

# %%
playlist

# %%
type(playlist)

# %%
playlist.keys()

# %%
playlist["items"][0]

# %% [markdown]
# ## Extracting a song from playlist

# %%
pprint.pprint(playlist)

# %%
playlist["items"][0]["track"]["id"]

# %%
play_song(playlist["items"][0]["track"]["id"])

# %%
print(list(playlist.keys())) # Let's look at items and total:
print("Total number of songs in the playlist: ",playlist["total"]) #  Let's check items:
len(playlist["items"]) # It is limited to 100 tracks, we will have to fix it:

# %% [markdown]
# ## Extracting the songs of a playlist

# %% [markdown]
# Pagination using "next"
# When you collect songs from a playlist using sp.playlist_tracks, you're limited by the limit parameter, which has a maximum (and default) value of 100. When the playlist has more than 100 songs, you have to collect them by navigating through the "pages" of the results.
#
# The parameter offset allows you to retrieve resuls starting at a certain position: if you start at position 101, you'd get the next "page" of results. An offset of 201 would give you the third page, and so on.
#
# The function sp.next() does the same, but in a simpler way: it can be used on the results from any request to directly retrieve the results for the next page.
#
# We can check whether there's a next page or not by accessing the key next on the results from any request.

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %% [markdown]
# ### Example with Jay Sean

# %%
jay_sean =get_playlist_tracks('spotify','37i9dQZF1DZ06evO2A96G4')

# %%
jay_sean[0].keys()

# %%
jay_sean[0]

# %%
jay_sean_id_list = []
for i in jay_sean:
    jay_sean_id_list.append(i['track']['id'])

# %%
audio_list =[]
for i in jay_sean_id_list:
    audio_list.append(sp.audio_features(i)[0])
audio_list

# %%
jay_sean_df = pd.DataFrame(audio_list)
jay_sean_df

# %%
pprint.pprint(jay_sean)

# %% [markdown]
# ### Example with rock

# %%
37i9dQZF1DWXRqgorJj26U

# %%
rock = get_playlist_tracks('Spotify','37i9dQZF1DWXRqgorJj26U')

# %%
rock_ids =[]
for i in rock:
    rock_ids.append(i['track']['id'])

# %%
play_song('5EWPGh7jbTNO2wakv8LjUI')

# %%
rock_af = []
for i in rock_ids:
    rock_af.append(sp.audio_features(i)[0])

# %%
pd.DataFrame(rock_af)

# %% [markdown]
# ## Optional(Extra)

# %% [markdown]
# ## Getting the artists of the playlist

# %%
def get_artists_from_track(track):
    return [artist["name"] for artist in track["artists"]]

# %%
def get_artists_from_playlist(playlist_id):
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    return list(set(artist for subset in [get_artists_from_track(track["track"]) for track in tracks_from_playlist] for artist in subset))

# %%
get_artists_from_playlist("4rnleEAOdmFAbRcNCgZMpY")
# Out:
# ['',
#  'Casso',
#  'Ja Rule',
#  'Zac Efron',
#  'Swizz Beatz',
#  'Bronski Beat',
#  'blackbear',
#  'Chad Kroeger',
#  'Pras',
#  'Ray Dalton',
#  'The Goo Goo Dolls',
#  'Ruelle',
#  'Ice Cube',
#  'City Girls',
#  'We The Kings',
#  'Trap City',
#  'R.E.M.',
#  'Sandra Lyng',
#  'Pariisin Kevät',
#  'Justin Stone',
#  'MASN',
#  'Dosdela',
#  'Lord Finesse,',
#  'Mikko Pohjola',
#  'Kygo',
#  'Tommee Profitt',
#  'The Script',
#  'Malmö',
#  'Kliff',
#  'Toro y Moi',
#  'Jamie Lynn Spears',
#  'Hot Shade',
#  'HEDEGAARD',
#  'Maiki',
#  'The Moose',
#  'Chance the Rapper',
#  'Teqkoi',
#  'Sexmane',
#  'Martti Vainaa',
#  'Andy Marsh',
#  'Dzeko',
#  'Ege Zulu',
#  'ILLENIUM',
#  'Dimitri Vangelis & Wyman',
#  'Sugababes',
#  'Smith & Thell',
#  'Far East Movement',
#  'Axwell',
#  'Saara Aalto',
#  'Eino Antiwäkki',
#  'Calboy',
#  'Starkillers',
#  'Toni Braxton',
#  'Mikko Harju',
#  'J. Cole',
#  'The Flexican',
#  'Death Cab for Cutie',
#  'Lennon Stella',
#  'Madison Love',
#  'Kid Ink',
#  'Styles P',
#  'Versace Henrik',
#  'Fasion',
#  'A Touch Of Class',
#  'Magnace',
#  'Eduardo Luzquiños',
#  'Lil Baby',
#  'TRAQULA',
#  'Kelly Rowland',
#  'Chris Linton',
#  'Baby Tate',
#  'Zen Cafe',
#  'Alex Newell',
#  'Zara Larsson',
#  'ppcocaine',
#  'Ida Paul',
#  'Zedd',
#  'Timbaland',
#  'Vesta',
#  'Sasha Alex Sloan',
#  'Danny Towers',
#  'Tones And I',
#  'Central Cee',
#  'CamelPhat',
#  'E-Rotic',
#  'Omar LinX',
#  'Coldplay',
#  'Wasted Penguinz',
#  'Benji Reyes',
#  'Vesala',
#  'Valvomo',
#  'Lilli Paasikivi',
#  'Stig Dogg',
#  'Touko',
#  'Redrama',
#  'Sista Prod',
#  'Redman',
#  'Lil Peep',
#  'Sweet Baby May',
#  'Sunrise Avenue',
#  'Ilta',
#  'Blush',
#  'Eevil Stöö',
#  'Juize',
#  'Mikkel Øwre',
#  'Tungevaag',
#  'Halestone',
#  'Dirty Disco Youth',
#  'iamjakehill',
#  'Goodboys',
#  'A2M',
#  'Töölön Ketterä',
#  'MGI',
#  'Jamelia',
#  'Rik Rok',
#  'Nick "Fierce" Fiorucci',
#  'TOTO',
#  'Elton John',
#  'Dash Berlin',
#  'Fergie',
#  'Portion Boys',
#  'Skandaali',
#  'JORI SJÖROOS',
#  'Jukka Poika',
#  'Westside Connection',
#  'LOLO',
#  'Marcus Schössow',
#  'Conan Gray',
#  'Maxx',
#  'Tyler, The Creator',
#  'Arman Cekin',
#  'Taras',
#  'PSY',
#  'The Theme Song',
#  'Trey Songz',
#  'Larry Ohh',
#  'EDEN',
#  'The Magician',
#  'WhoHeem',
#  'Lukas Leon',
#  'YK Osiris',
#  'Siine',
#  'Sigma',
#  'Jhené Aiko',
#  'Verdine White',
#  'Big Sean',
#  'Britt Daley',
#  'Sammie',
#  'Keala Settle',
#  'CJ',
#  'Bow Wow',
#  'HVME',
#  'Aaro630',
#  'Elen Levon',
#  'Irina',
#  'Calpurnia',
#  'Machine Gun Kelly',
#  'Michael Schulte',
#  'Jamie Scott',
#  'Tinashe',
#  'Jeffrey James',
#  'Lit',
#  'Nuorihylly',
#  'Emila',
#  'Michael Bolton',
#  'LSD',
#  'Solo Lucci',
#  'Martin Solveig',
#  'Lil Gotit',
#  'Dzeko & Torres',
#  'Aksel Kankaanranta',
#  'Cookiee Kawaii',
#  'Duki',
#  'Lil Yachty',
#  '$uicideboy$',
#  'Attom',
#  'The Oddictions',
#  'Hkeem',
#  'Ameerah',
#  'Alvaro Soler',
#  'Larray',
#  'Lil Revive',
#  'Jaden Hossler',
#  'Coolio',
#  'Ruel',
#  'Fousheé',
#  'líue',
#  'Jope Ruonansuu',
#  'Yung Bae',
#  'Brayden',
#  'Ola',
#  'Lenka',
#  'Willow Sage Hart',
#  'Saweetie',
#  'Ruudolf',
#  'Matisse & Sadko',
#  'Das EFX',
#  'Benny Sings',
#  'Hey Violet',
#  'Jay Cosmic',
#  'Ina Wroldsen',
#  'KSI',
#  'Infinity',
#  'kent',
#  'Falling In Reverse',
#  'Kristinia DeBarge',
#  'Mikky Ekko',
#  'Indiiana',
#  'Lil Skies',
#  'Lucenzo',
#  'Chisu',
#  'Ilsey',
#  'Getter Jaani',
#  'Topic',
#  'Tove Lo',
#  'Metro Boomin',
#  'The Boy Next Door',
#  'Mattyeux',
#  'Yello',
#  'Nyla',
#  'Laurell',
#  'The Game',
#  'mansionz',
#  'Luh Kel',
#  'ALMA',
#  'Kristiina Brask',
#  'fun.',
#  'Y2K',
#  'Lauri Tähkä & Elonkerjuu',
#  'Chief Keef',
#  'Robin Packalen',
#  'Geto Boys',
#  'Lil Rain',
#  'X Ambassadors',
#  'Busy Signal',
#  'Lene Marlin',
#  'Venior',
#  'Leighton Meester',
#  'VASSY',
#  'Mascara',
#  'Riki Sorsa',
#  'Knife Party',
#  'Morgan Page',
#  'Aika',
#  'Herba',
#  'Tony Arzadon',
#  'Mascolo',
#  'Oh Wonder',
#  'Chelsea Cutler',
#  'Danny Quest',
#  'Elonkerjuu',
#  'Mumford & Sons',
#  'Arron',
#  'Wyd Benny',
#  'DripReport',
#  'Milky Chance',
#  'Hayley Kiyoko',
#  'Timeflies',
#  'The Prince Karma',
#  'Banx & Ranx',
#  'Megan Nicole',
#  'Imanbek',
#  'Lil Uzi Vert',
#  'Maisa',
#  'LUCA',
#  'Pasi ja Anssi',
#  'James Blake',
#  'Normani',
#  'unheard',
#  'Loote',
#  'Artem x Yonas',
#  'LittleJayneyCakes',
#  'Bassjackers',
#  'Reset',
#  'YOUNGHEARTED',
#  'VIZE',
#  'Vinny West',
#  'Lidl Stingy',
#  'Ramz',
#  'Lil Mosey',
#  'Maija Vilkkumaa',
#  'HRVY',
#  'Lil Pump',
#  'Alex Aiono',
#  'Kerli',
#  'Haloo Helsinki!',
#  'alt-J',
#  'Ian Everson',
#  "Rag'n'Bone Man",
#  'Kim Herold',
#  'Samuli Edelmann',
#  'Chris Willis',
#  'WIL',
#  'NATTI NATASHA',
#  't.A.T.u.',
#  'Peter Kuli',
#  'Remy Ma',
#  'BIA',
#  'Anna Eriksson',
#  'Olivia Rodrigo',
#  'Olly Murs',
#  'Supergrass',
#  'Mikko',
#  'Oso Faneto',
#  'Oliver Heldens',
#  'Kings of Leon',
#  'Dawin',
#  'Mindless Self Indulgence',
#  'Rick Astley',
#  'Vedo',
#  'Gracias',
#  'Yona',
#  'White Town',
#  '24kGoldn',
#  'Ali Gatie',
#  'Anders Nilsen',
#  'Julma H',
#  '6 Dogs',
#  'Say Lou Lou',
#  'Vula',
#  'Bonnie McKee',
#  'Post Malone',
#  'KOI',
#  'Shortster 0161',
#  'Samu Haber',
#  'Jesse McCartney',
#  'SLS',
#  'London On Da Track',
#  'Murcy',
#  'Johnta Austin',
#  'Sunnery James & Ryan Marciano',
#  'Lil Nas X',
#  'JJani',
#  'Linda',
#  'Billy Marchiafava',
#  'ROZES',
#  'Ultra Bra',
#  'Lil Xan',
#  'WALK THE MOON',
#  'Spree Wilson',
#  'Leyla Blue',
#  'Baby Keem',
#  'Antti Tuisku',
#  'Char Ligera',
#  'Juliander',
#  'Sleepy Tom',
#  'Moon OA',
#  'Boehm',
#  'Ringnes-Ronny',
#  'Martin Garrix',
#  'Jonas Vogel',
#  'Ilpo Kaikkonen',
#  'Trisha Paytas',
#  'Popeda',
#  'DJ Sequenza',
#  'Darko',
#  'Ivone Cerdan',
#  'iLOVEFRiDAY',
#  'DJ Frank E',
#  'So Loki',
#  'Kim Petras',
#  'Anitta',
#  'Studio Killers',
#  'Bazzi',
#  'Ghostemane',
#  'Eric Bellinger',
#  'Ciara',
#  'Hannah Robinson',
#  'Rat City',
#  'Rich Homie Quan',
#  'Laura Närhi',
#  'Fleurie',
#  'YoungBoy Never Broke Again',
#  'The Boyboy West Coast',
#  'Contiez',
#  'Peter Franzen',
#  'Pete Parkkonen',
#  'James Brown',
#  'Molella',
#  'Sam Fischer',
#  'Prinssi Jusuf',
#  'Bizi',
#  'Jontte Valosaari',
#  'Louis Tomlinson',
#  'WSTRN',
#  'Vaboh',
#  'Chase Atlantic',
#  'Aries',
#  'Good Charlotte',
#  'Jason Evigan',
#  'Jack Harlow',
#  'Otto Knows',
#  'T-Pain',
#  'Piso 21',
#  'Tuomas Holopainen',
#  'Videoclub',
#  'Jadakiss',
#  'Molly Brazy',
#  'Tiësto',
#  'Nelly Furtado',
#  'Freedom Williams',
#  'Grits',
#  'Matchbox Twenty',
#  'Party Favor',
#  'Boys Noize',
#  'Fintelligens',
#  'Tarrus Riley',
#  'Gabrielle',
#  'Da Tweekaz',
#  'Grimes',
#  'Josh A',
#  'Selena Gomez',
#  'Bill Wurtz',
#  'Eva Simons',
#  'Jussi 69',
#  'Aya Nakamura',
#  'LL COOL J',
#  'Twista',
#  'Vory',
#  'Redfoo',
#  'Archie Cruz',
#  'Jay Hardway',
#  'Naomi Scott',
#  'phem',
#  'Ayo & Teo',
#  'NCO',
#  'Ness The Kid',
#  'Georgia Ku',
#  'Becky Hill',
#  'Gryffin',
#  'Dante Klein',
#  'Antti Railio',
#  'Alissa Violet',
#  'Stefflon Don',
#  'Kid Bloom',
#  'Sage The Gemini',
#  'Cassadee Pope',
#  'Ryan Leslie',
#  'Alexander 23',
#  'Etham',
#  'Niko Saarinen',
#  'Joseph',
#  'Justin Timberlake',
#  'Treyy G',
#  'Pale Waves',
#  'Steve Aoki',
#  'Tommy Trash',
#  'Lil Kayla',
#  'Apulanta',
#  'Measure',
#  'Billie Eilish',
#  'MHD',
#  'Andreea D',
#  'Au/Ra',
#  'Limp Bizkit',
#  'Drake',
#  'Lauv',
#  'Powfu',
#  'Satin Circus',
#  'Sugarland',
#  'Sum 41',
#  'Dopant Beats',
#  'My Chemical Romance',
#  'Seeb',
#  'BeatKing',
#  'O-Zone',
#  'Sneazzy',
#  'Wallows',
#  'Ozuna',
#  'FINNEAS',
#  'JVKE',
#  'Lucas',
#  'Måns Zelmerlöw',
#  'Kyla',
#  'Seinabo Sey',
#  'Ashlee Simpson',
#  'PnB Rock',
#  'Ca$his',
#  'Roddy Ricch',
#  'J Spooks',
#  'Fatman Scoop',
#  'Classified',
#  'Foo Fighters',
#  'McCafferty',
#  'Fuse ODG',
#  'TEN TIMES',
#  'Nina Nesbitt',
#  'Amy Diamond',
#  'Papa Roach',
#  'Matt Squire',
#  'Thundercat',
#  'Bonnie Tyler',
#  'A$AP Rocky',
#  'Alfons',
#  'Spongebob Squarepants',
#  'Cheek',
#  'Future',
#  'VIIVI',
#  'Sonique',
#  'Starley',
#  'Anne-Marie',
#  'Elle King',
#  'VINAI',
#  'Tango-Teemu',
#  'Pop Smoke',
#  'SoMo',
#  'Kelis',
#  'Annika Eklund',
#  'Blaise',
#  'Indica',
#  'Jay Prince',
#  'Penelope Scott',
#  'Matthew Wilder',
#  'Kill The Noise',
#  'Nicole Scherzinger',
#  'J. Karjalainen Yhtyeineen',
#  'girl in red',
#  'Alyson Stoner',
#  'Rihanna',
#  'Kranium',
#  'Foreigner',
#  'Descemer Bueno',
#  'Crystal Castles',
#  'Ryos',
#  'Elokuu',
#  'The Lonely Island',
#  'Busta Rhymes',
#  'Adizi X Typelik',
#  'KANDY',
#  'A$AP Ferg',
#  'Vepu',
#  'Seezyn',
#  'Krewella',
#  'Lord Est',
#  'Isaiah Firebrace',
#  'Vince Staples',
#  'Joznez',
#  'Bethany Mota',
#  'Chamillionaire',
#  'Gusttavo Lima',
#  'DJ Cassidy',
#  'DJ DX',
#  'Lauri Ylönen',
#  'Arttu Wiskari',
#  'K-System',
#  'TWENTY88',
#  'MGMT',
#  'Jeremy Zucker',
#  'Alicia Keys',
#  'william',
#  'The Greatest Showman Ensemble',
#  'Zak Abel',
#  'OMI',
#  'WTF!',
#  'Keko Salata',
#  'Sean Paul',
#  'Kooma',
#  'B.o.B',
#  'Dreezy',
#  '9lokknine',
#  'Mariah Carey',
#  'V V Brown',
#  'R3HAB',
#  'Jamie Foxx',
#  'BESS',
#  'Pehmee Goo',
#  'Alex Vargas',
#  'Villayn',
#  'Slim Mill',
#  'Shakira',
#  'Setä Tamu',
#  'Zachary Knowles',
#  'Teleks',
#  'Sirah',
#  'Little Sis Nora',
#  'Anuel AA',
#  '90s allstars',
#  'Guy Sebastian',
#  'Miriam Bryant',
#  'Giveon',
#  'Sami Saari',
#  'ABBA',
#  'SNBRN',
#  'Anna Maria Perez de Taglé',
#  'DMX',
#  'Jaden',
#  'Neea',
#  'Austin Mahone',
#  'Gabry Ponte',
#  'Michelle Williams',
#  'PapiPike',
#  'Sara Kays',
#  'frzndisciple',
#  'Dean Lewis',
#  'Jon Bellion',
#  'Anastacia',
#  'Monica',
#  'Sir Chloe',
#  'Kalle Kinos',
#  'Abandoning Sunday',
#  'JR Serpent',
#  'Boyzone',
#  'Jax Jones',
#  'Aki Tykki',
#  'Juice WRLD',
#  'Oz Sparx',
#  'Scarlet',
#  'Gotye',
#  'Pink Guy',
#  'Janelle Monáe',
#  'Michael Constantino',
#  'Wheatus',
#  'The Carters',
#  'Eric Nally',
#  'Radiohead',
#  'Missy Elliott',
#  'Lili Reinhart',
#  'Hayla',
#  'Maddix',
#  'Bebe Rexha',
#  'Rex Orange County',
#  'Mohombi',
#  'Mike WiLL Made-It',
#  'Yung Gravy',
#  'dvsn',
#  'DJ Khaled',
#  'Annabel Jones',
#  'The All-American Rejects',
#  'BloodPop®',
#  'Leevi and the leavings',
#  'Rizzle Kicks',
#  'Omar Varela',
#  'Skrillex',
#  'Jacob Sartorius',
#  'Paramore',
#  'Hot Chelle Rae',
#  'Foxes',
#  'Maroon 5',
#  'Lil Sage x JustSeAbu x MVD J€¥$ON',
#  'Demi Lovato',
#  'Broono',
#  'Vanilla Ice',
#  'Soulja Boy',
#  'Six-Two',
#  'Offset',
#  'Ocean x KungFu',
#  'Stormzy',
#  'Cousin Stizz',
#  'Cazzu',
#  'Donny',
#  'Hayden James',
#  'Erakossa',
#  'The Ronettes',
#  'Maren Morris',
#  'BONES',
#  'Kimbra',
#  'Wolfpack',
#  'LIOHN',
#  'Reino Nordin',
#  '6LACK',
#  'AIIVAWN',
#  'Arttu Lindeman',
#  "Charlie's Angels",
#  'Young Nudy',
#  'Fatboy Slim',
#  'Temur',
#  'Cast of Shake It Up: Break It Down',
#  'Internet Money',
#  'mayklove',
#  'Good Times Ahead',
#  'Trouble',
#  'Jennifer Lopez',
#  'La La La La',
#  'Tears For Fears',
#  'VG+',
#  'Jem Cooke',
#  'Mitch Crown',
#  'Danny',
#  'Laidback Luke',
#  'KHEA',
#  'Lil Toe',
#  'Elias Gould',
#  'Pihlaja',
#  'Dayglow',
#  'Ryan Riback',
#  'Joel Adams',
#  'Mike Williams',
#  'OMC',
#  'BigKlit',
#  'Mellen Gi',
#  'Wisin',
#  "Olivia O'Brien",
#  '27CLUB',
#  'BEHM',
#  'Pää-äijät',
#  'The Corrs',
#  'Borgeous',
#  'Jasiah',
#  'MØ',
#  'The Throne',
#  'BROCKHAMPTON',
#  'Tez Cadey',
#  'Jani Wickholm',
#  'Rae Sremmurd',
#  'Yung Hilly',
#  'Lil Jon & The East Side Boyz',
#  'Lakko',
#  'Lukas Meijer',
#  'Johanna Kurkela',
#  'Arizona Zervas',
#  'JUVENILE',
#  'Kauniit & Uhkarohkeat',
#  'Mabel',
#  "Waldo's People",
#  'Drenchill',
#  'Jared Lee',
#  'CAZZETTE',
#  'Lea in the Mix',
#  'Hight',
#  'Tiisu',
#  'Mandi',
#  '3OH!3',
#  'SAMUEL',
#  'Tinie Tempah',
#  'Vesa-Matti Loiri',
#  'Modern Talking',
#  'Sophia Annello',
#  'DJ BL3ND',
#  'benny blanco',
#  'Louis The Child',
#  'Roy Woods',
#  'The Flint Chozen Choir',
#  'Ryanning',
#  'Current Joys',
#  'Migos',
#  'DJ Katch',
#  'PNAU',
#  'Tony Junior',
#  'Audien',
#  'Robin Schulz',
#  'Mally Mall',
#  'Marc E. Bassy',
#  'Masked Wolf',
#  'Bobby Rock',
#  'Adèle Castillon',
#  'St James',
#  'Lykke Li',
#  'Nbdy',
#  'DVBBS',
#  'James Bay',
#  'Cash Cash',
#  'Nickelback',
#  'Devault',
#  'The Kid LAROI',
#  'Veela',
#  'Roope Salminen & Koirat',
#  'Vilma Alina',
#  'Michael Marshall',
#  'Tierra Whack',
#  'La Cream',
#  'Pentatonix',
#  'Grace Phipps',
#  'El Cata',
#  'Chase',
#  'Ethan Fields',
#  'ibe',
#  'Bella Thorne',
#  'Tomppabeats',
#  'Kali Uchis',
#  'Lakim',
#  'BACALL',
#  'The Cataracs',
#  'Kamaiyah',
#  'A.G.',
#  'Tyrone Briggs',
#  'Sandro Cavazza',
#  'Georgi Kay',
#  'Sam Smith',
#  'ROSALÍA',
#  'Marshmello',
#  'WanMor',
#  'Diego Miranda',
#  'Ellips',
#  'Bogart Co.',
#  'Belly',
#  'Rodríguez',
#  'The Lumineers',
#  'Amy Macdonald',
#  'Charli XCX',
#  'Ultradiox',
#  'DJ Martin ElectroSpin',
#  'Tham Sway',
#  'Popcaan',
#  'ILARI',
#  'Cosmo Sheldrake',
#  'W&W',
#  'Filip Jenven',
#  'Promoting Sounds',
#  'Lil Wayne',
#  'Blueface',
#  'Phil Jay',
#  'Are',
#  'BLACKPINK',
#  'Jack & Jack',
#  'Yung Pinch',
#  'Juulia',
#  "Why Don't We",
#  'OBN Dev',
#  'Tim McMorris',
#  'Queen',
#  'Denzel Curry',
#  'Christina Perri',
#  'Alexis Jordan',
#  'MKDMSK',
#  'Jenni Vartiainen',
#  'Eve',
#  'Glass Animals',
#  'Paul Rey',
#  'Stromae',
#  'Walt Ribeiro',
#  'Don Toliver',
#  'Adam Levine',
#  'Eduardo Nascimento',
#  'Shaggy',
#  'Yung Anime',
#  'Paperi T',
#  'DJ Sammy',
#  'Madden',
#  'Fabe',
#  'Pouya',
#  'Surfaces',
#  'Fall Out Boy',
#  'Lyttä',
#  'Tim Bergling',
#  'Russ',
#  'Meghan Trainor',
#  'Erin',
#  'Janieck',
#  'Aimie Atkinson',
#  'Qulinez',
#  'Naomi Wild',
#  'Emily Warren',
#  'NF',
#  'Gwen Stefani',
#  'STEREO',
#  'Death Grips',
#  'Yade Lauren',
#  'Alex Joseph',
#  'Juno',
#  'bbno$',
#  'SNAP!',
#  'Luke Combs',
#  'Brando',
#  'Dax',
#  'SAYGRACE',
#  'Tiktak',
#  'Dingo',
#  'Tuure Boelius',
#  'Amba Shepherd',
#  'Wintertime',
#  'Khalid',
#  'Fernando',
#  'Daya',
#  'Jay Alvarrez',
#  'Booboo Stewart',
#  'Tainy',
#  'Niall Horan',
#  'Ty Dolla $ign',
#  'MD$',
#  'Eiffel 65',
#  'Chrishan',
#  'Tom & Hills',
#  'Bananarama',
#  'Mike Posner',
#  'The Royalties STHLM',
#  'Playboi Carti',
#  'Daze',
#  'Dropgun',
#  'Ressu Redford',
#  'Jari Sillanpää',
#  'Jonihey',
#  'Corona',
#  'Ross Lynch',
#  'Comethazine',
#  'Ellinoora',
#  'Jez Dior',
#  'Dan Caplen',
#  'Alexandra Stan',
#  'Talk Talk',
#  'Devon Baldwin',
#  'Egotrippi',
#  'WILLOW',
#  'Ricky Martin',
#  'Kasmir',
#  'Kodak Black',
#  'KAROL G',
#  'Backstreet Boys',
#  'Tasis',
#  'Nicco',
#  'Shokk',
#  'Cal Chuchesta',
#  'Poju',
#  'eli.',
#  'Louisa Johnson',
#  'Molchat Doma',
#  'Ryan Lewis',
#  'Aku Hirviniemi',
#  'Krista Siegfrids',
#  'Labrinth',
#  'Kesha',
#  'DubVision',
#  'Goody Grace',
#  'Andi',
#  'Meek Mill',
#  'Tony Igy',
#  'Beats And Styles',
#  'Hilary Duff',
#  'Arash',
#  'Joseph Williams',
#  'Echosmith',
#  'Mansesteri',
#  'Frank Ocean',
#  'Riff Raff',
#  'Tom Walker',
#  'Black Eyed Peas',
#  'Bastille',
#  'Tiny Tim',
#  'Phil Collins',
#  'Fatboy L',
#  'YB026',
#  'Quavo',
#  'Jordin Sparks',
#  'jambo',
#  'DISCO',
#  'Lady Gaga',
#  'Kevin Gates',
#  'BENEE',
#  'Drake Bell',
#  'Harry Fraud',
#  'Nirvana',
#  'Lil Gnar',
#  'Axel Kala',
#  'Juha Tapio',
#  'Jonna Tervomaa',
#  'Ruben',
#  'Lil Tjay',
#  'Victoria Justice',
#  'costee',
#  'Estelle',
#  'Florence Welch',
#  'DJ Fresh',
#  'Isac Elliot',
#  'Jack McManus',
#  'Hector',
#  'The Neighbourhood',
#  'John & Michel',
#  'Vaahteramäen Nege',
#  'Darius & Finlay',
#  'Bryce Vine',
#  'lentra',
#  'Whethan',
#  'Duffy',
#  'Live for the weekend',
#  'LIL MAYO',
#  'Kehlani',
#  'Buddy',
#  'Vance Joy',
#  'Rvssian',
#  'Jessie Reyez',
#  'Wanz',
#  'JACKBOYS',
#  'Aamupojat',
#  'Alanis Morissette',
#  'Nopsajalka',
#  'Jake Reese',
#  'Britney Spears',
#  'Icona Pop',
#  'Do',
#  'Lady A',
#  'GoonRock',
#  'Wreck',
#  'S3RL',
#  'Ocho Drippin',
#  'Snakehips',
#  'Dani Poppitt',
#  'Ghostface Killah',
#  'Spencer Barnett',
#  'Vengaboys',
#  '90s Maniacs',
#  'Kuselofte',
#  'Ludacris',
#  'Salti',
#  'Friday Pilots Club',
#  'Example',
#  'N.W.A.',
#  'Ideaali & Jay Who?',
#  'XS Project',
#  'Starrah',
#  'Aly & AJ',
#  'Fellatia Geisha',
#  ...]

# %% [markdown]
# # Getting albums

# %% [markdown]
# In this section we will work with albums to extract information. We will start by extracting all the albums of an artist.

# %%
def get_albums_from_artist(artist_id):
    results = sp.artist_albums(artist_id, limit = 50,country="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# Same for albums ids
def get_album_ids_from_artist(artist_id):
    results = sp.artist_albums(artist_id, limit = 50)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return [track["id"] for track in tracks]

# %% [markdown]
# Example: Coldplay

# %%
coldplay_id = "4gzpq5DPGxSnKTe4SA8HAU"
coldplay_albums = get_albums_from_artist(coldplay_id)
coldplay_album_ids = get_album_ids_from_artist(coldplay_id)

# Check artists that played with coldplay
set([artist["name"] for track in coldplay_albums for artist in track["artists"]])

# %% [markdown]
# ## Getting the songs of a given album

# %%
def get_track_ids_from_albums(album_ids):
    return list(set([i["id"] for j in album_ids for i in sp.album(j)["tracks"]["items"]]))

# %%
coldplay_songs = get_track_ids_from_albums(coldplay_album_ids)

len(coldplay_songs)

# %%
sublist_length = len(chill_ids) // 4

# Use list slicing to create 4 sub-lists
sublist1 = chill_ids[:sublist_length]
sublist2 = chill_ids[sublist_length:2 * sublist_length]
sublist3 = chill_ids[2 * sublist_length:3 * sublist_length]
sublist4 = chill_ids[3 * sublist_length:]

chill_af = []
for i in sublist1:
    chill_af.append(sp.audio_features(i)[0])
for i in sublist2:
    chill_af.append(sp.audio_features(i)[0])
for i in sublist3:
    chill_af.append(sp.audio_features(i)[0])
for i in sublist4:
    chill_af.append(sp.audio_features(i)[0])

# %% [markdown]
# ## Play list chill

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
chill_p = get_playlist_tracks('Spotify','7j9Zqm9NaApNBmxYiSFUlP')

# %%
chill_p
# Out:
# [{'added_at': '2023-11-16T19:23:41Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yeahthejacko'},
#    'href': 'https://api.spotify.com/v1/users/yeahthejacko',
#    'id': 'yeahthejacko',
#    'type': 'user',
#    'uri': 'spotify:user:yeahthejacko'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/27CcPFsy79qUbXjqWSDkjj'},
#       'href': 'https://api.spotify.com/v1/artists/27CcPFsy79qUbXjqWSDkjj',
#       'id': '27CcPFsy79qUbXjqWSDkjj',
#       'name': 'Midnight Dance Party',
#       'type': 'artist',
#       'uri': 'spotify:artist:27CcPFsy79qUbXjqWSDkjj'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1ZXyz6qwgUbhWMvhUyTGvE'},
#     'href': 'https://api.spotify.com/v1/albums/1ZXyz6qwgUbhWMvhUyTGvE',
#     'id': '1ZXyz6qwgUbhWMvhUyTGvE',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e43701452fd6477bce5fbfb3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e43701452fd6477bce5fbfb3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e43701452fd6477bce5fbfb3',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'closer to u',
#     'release_date': '2023-11-17',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:1ZXyz6qwgUbhWMvhUyTGvE'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/27CcPFsy79qUbXjqWSDkjj'},
#      'href': 'https://api.spotify.com/v1/artists/27CcPFsy79qUbXjqWSDkjj',
#      'id': '27CcPFsy79qUbXjqWSDkjj',
#      'name': 'Midnight Dance Party',
#      'type': 'artist',
#      'uri': 'spotify:artist:27CcPFsy79qUbXjqWSDkjj'}],
#    'disc_number': 1,
#    'duration_ms': 259849,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USA2P2346910'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4YCVbp6suJ2Ayk9EtWQJuR'},
#    'href': 'https://api.spotify.com/v1/tracks/4YCVbp6suJ2Ayk9EtWQJuR',
#    'id': '4YCVbp6suJ2Ayk9EtWQJuR',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'closer to u',
#    'popularity': 20,
#    'preview_url': 'https://p.scdn.co/mp3-preview/899293a968721920c11cb0346070e3753c991f04?cid=d93283ae0ac74ebc9d1ecc472254bada',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4YCVbp6suJ2Ayk9EtWQJuR'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-11-18T08:52:17Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yeahthejacko'},
#    'href': 'https://api.spotify.com/v1/users/yeahthejacko',
#    'id': 'yeahthejacko',
#    'type': 'user',
#    'uri': 'spotify:user:yeahthejacko'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1reJK6xw6Lu0r1PMoTUTDj'},
#       'href': 'https://api.spotify.com/v1/artists/1reJK6xw6Lu0r1PMoTUTDj',
#       'id': '1reJK6xw6Lu0r1PMoTUTDj',
#       'name': 'Club Angel',
#       'type': 'artist',
#       'uri': 'spotify:artist:1reJK6xw6Lu0r1PMoTUTDj'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5qEGkaG2wMcn787eEwGkhK'},
#     'href': 'https://api.spotify.com/v1/albums/5qEGkaG2wMcn787eEwGkhK',
#     'id': '5qEGkaG2wMcn787eEwGkhK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27391e21a46ebb596e9453dc7c3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0291e21a46ebb596e9453dc7c3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485191e21a46ebb596e9453dc7c3',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Cry',
#     'release_date': '2023-11-16',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5qEGkaG2wMcn787eEwGkhK'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1reJK6xw6Lu0r1PMoTUTDj'},
#      'href': 'https://api.spotify.com/v1/artists/1reJK6xw6Lu0r1PMoTUTDj',
#      'id': '1reJK6xw6Lu0r1PMoTUTDj',
#      'name': 'Club Angel',
#      'type': 'artist',
#      'uri': 'spotify:artist:1reJK6xw6Lu0r1PMoTUTDj'}],
#    'disc_number': 1,
#    'duration_ms': 230074,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'AUVWE2301216'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2HhhhHfVEmz09NAb0FxgDW'},
#    'href': 'https://api.spotify.com/v1/tracks/2HhhhHfVEmz09NAb0FxgDW',
#    'id': '2HhhhHfVEmz09NAb0FxgDW',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Cry',
#    'popularity': 33,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8de942481225745f3820a632adceab9cee5d9312?cid=d93283ae0ac74ebc9d1ecc472254bada',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2HhhhHfVEmz09NAb0FxgDW'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-11-16T19:04:17Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yeahthejacko'},
#    'href': 'https://api.spotify.com/v1/users/yeahthejacko',
#    'id': 'yeahthejacko',
#    'type': 'user',
#    'uri': 'spotify:user:yeahthejacko'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/68rU1sdZ0HjxjEC5YnSmao'},
#       'href': 'https://api.spotify.com/v1/artists/68rU1sdZ0HjxjEC5YnSmao',
#       'id': '68rU1sdZ0HjxjEC5YnSmao',
#       'name': 'Riordan',
#       'type': 'artist',
#       'uri': 'spotify:artist:68rU1sdZ0HjxjEC5YnSmao'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7E0q2fAykseBKfLY7X53jJ'},
#     'href': 'https://api.spotify.com/v1/albums/7E0q2fAykseBKfLY7X53jJ',
#     'id': '7E0q2fAykseBKfLY7X53jJ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ac785450fbdb3b4e53c57572',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ac785450fbdb3b4e53c57572',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ac785450fbdb3b4e53c57572',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Needle On The Record',
#     'release_date': '2023-11-10',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:7E0q2fAykseBKfLY7X53jJ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/68rU1sdZ0HjxjEC5YnSmao'},
#      'href': 'https://api.spotify.com/v1/artists/68rU1sdZ0HjxjEC5YnSmao',
#      'id': '68rU1sdZ0HjxjEC5YnSmao',
#      'name': 'Riordan',
#      'type': 'artist',
#      'uri': 'spotify:artist:68rU1sdZ0HjxjEC5YnSmao'}],
#    'disc_number': 1,
#    'duration_ms': 186625,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'US39N2389841'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5qKuF0NtvWVn5UarAgyli3'},
#    'href': 'https://api.spotify.com/v1/tracks/5qKuF0NtvWVn5UarAgyli3',
#    'id': '5qKuF0NtvWVn5UarAgyli3',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Needle On The Record',
#    'popularity': 50,
#    'preview_url': 'https://p.scdn.co/mp3-preview/055a6ff6dc3151f5516fa2819ff3606c05b6fbe6?cid=d93283ae0ac74ebc9d1ecc472254bada',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5qKuF0NtvWVn5UarAgyli3'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-11-18T08:52:17Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yeahthejacko'},
#    'href': 'https://api.spotify.com/v1/users/yeahthejacko',
#    'id': 'yeahthejacko',
#    'type': 'user',
#    'uri': 'spotify:user:yeahthejacko'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6ZHeg2Op5ZkNppXbNLSglj'},
#       'href': 'https://api.spotify.com/v1/artists/6ZHeg2Op5ZkNppXbNLSglj',
#       'id': '6ZHeg2Op5ZkNppXbNLSglj',
#       'name': 'Willaris. K',
#       'type': 'artist',
#       'uri': 'spotify:artist:6ZHeg2Op5ZkNppXbNLSglj'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0DqR5aQYPz1s2M3YbycLMJ'},
#       'href': 'https://api.spotify.com/v1/artists/0DqR5aQYPz1s2M3YbycLMJ',
#       'id': '0DqR5aQYPz1s2M3YbycLMJ',
#       'name': 'jamesjamesjames',
#       'type': 'artist',
#       'uri': 'spotify:artist:0DqR5aQYPz1s2M3YbycLMJ'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/01yboJTcG4g6l7x05oWotG'},
#     'href': 'https://api.spotify.com/v1/albums/01yboJTcG4g6l7x05oWotG',
#     'id': '01yboJTcG4g6l7x05oWotG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27345ef90e8059b2dc55bae98b2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0245ef90e8059b2dc55bae98b2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485145ef90e8059b2dc55bae98b2',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Silversun',
#     'release_date': '2023-11-17',
#     'release_date_precision': 'day',
#     'total_tracks': 4,
#     'type': 'album',
#     'uri': 'spotify:album:01yboJTcG4g6l7x05oWotG'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6ZHeg2Op5ZkNppXbNLSglj'},
#      'href': 'https://api.spotify.com/v1/artists/6ZHeg2Op5ZkNppXbNLSglj',
#      'id': '6ZHeg2Op5ZkNppXbNLSglj',
#      'name': 'Willaris. K',
#      'type': 'artist',
#      'uri': 'spotify:artist:6ZHeg2Op5ZkNppXbNLSglj'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0DqR5aQYPz1s2M3YbycLMJ'},
#      'href': 'https://api.spotify.com/v1/artists/0DqR5aQYPz1s2M3YbycLMJ',
#      'id': '0DqR5aQYPz1s2M3YbycLMJ',
#      'name': 'jamesjamesjames',
#      'type': 'artist',
#      'uri': 'spotify:artist:0DqR5aQYPz1s2M3YbycLMJ'}],
#    'disc_number': 1,
#    'duration_ms': 299387,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'AULI02354800'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0lIOamNC6EMXu1AgPyzSTD'},
#    'href': 'https://api.spotify.com/v1/tracks/0lIOamNC6EMXu1AgPyzSTD',
#    'id': '0lIOamNC6EMXu1AgPyzSTD',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/6J3UxRhutXB7ANSfvQVmGE'},
#     'href': 'https://api.spotify.com/v1/tracks/6J3UxRhutXB7ANSfvQVmGE',
#     'id': '6J3UxRhutXB7ANSfvQVmGE',
#     'type': 'track',
#     'uri': 'spotify:track:6J3UxRhutXB7ANSfvQVmGE'},
#    'name': 'Bullet Train To Paris',
#    'popularity': 30,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0lIOamNC6EMXu1AgPyzSTD'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-11-18T08:52:17Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yeahthejacko'},
#    'href': 'https://api.spotify.com/v1/users/yeahthejacko',
#    'id': 'yeahthejacko',
#    'type': 'user',
#    'uri': 'spotify:user:yeahthejacko'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0G5lZVxoMwoY8oV6zR8E7k'},
#       'href': 'https://api.spotify.com/v1/artists/0G5lZVxoMwoY8oV6zR8E7k',
#       'id': '0G5lZVxoMwoY8oV6zR8E7k',
#       'name': 'Mashd N Kutcher',
#       'type': 'artist',
#       'uri': 'spotify:artist:0G5lZVxoMwoY8oV6zR8E7k'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3NiRKK6MNFyeUWzGz57oXq'},
#     'href': 'https://api.spotify.com/v1/albums/3NiRKK6MNFyeUWzGz57oXq',
#     'id': '3NiRKK6MNFyeUWzGz57oXq',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a0fa630cfa9048a349c053cb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a0fa630cfa9048a349c053cb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a0fa630cfa9048a349c053cb',
#       'width': 64}],
#     'is_playable': True,
#     'name': "IT'S ALRIGHT",
#     'release_date': '2023-11-17',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3NiRKK6MNFyeUWzGz57oXq'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0G5lZVxoMwoY8oV6zR8E7k'},
#      'href': 'https://api.spotify.com/v1/artists/0G5lZVxoMwoY8oV6zR8E7k',
#      'id': '0G5lZVxoMwoY8oV6zR8E7k',
#      'name': 'Mashd N Kutcher',
#      'type': 'artist',
#      'uri': 'spotify:artist:0G5lZVxoMwoY8oV6zR8E7k'}],
#    'disc_number': 1,
#    'duration_ms': 140538,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'AUCN32300221'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0LKAbdXTieXQrjuImr9B9u'},
#    'href': 'https://api.spotify.com/v1/tracks/0LKAbdXTieXQrjuImr9B9u',
#    'id': '0LKAbdXTieXQrjuImr9B9u',
#    'is_local': False,
#    'is_playable': True,
#    'name': "IT'S ALRIGHT",
#    'popularity': 38,
#    'preview_url': 'https://p.scdn.co/mp3-preview/145f03ddc658975737157f0304c2082c169a802c?cid=d93283ae0ac74ebc9d1ecc472254bada',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0LKAbdXTieXQrjuImr9B9u'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-11-16T19:04:17Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yeahthejacko'},
#    'href': 'https://api.spotify.com/v1/users/yeahthejacko',
#    'id': 'yeahthejacko',
#    'type': 'user',
#    'uri': 'spotify:user:yeahthejacko'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1GuqTQbuixFHD6eBkFwVcb'},
#       'href': 'https://api.spotify.com/v1/artists/1GuqTQbuixFHD6eBkFwVcb',
#       'id': '1GuqTQbuixFHD6eBkFwVcb',
#       'name': 'Sammy Virji',
#       'type': 'artist',
#       'uri': 'spotify:artist:1GuqTQbuixFHD6eBkFwVcb'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/628CN0UzuPsstc678cQ5Sn'},
#     'href': 'https://api.spotify.com/v1/albums/628CN0UzuPsstc678cQ5Sn',
#     'id': '628CN0UzuPsstc678cQ5Sn',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d5b8fa0ff5dee9da54847694',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d5b8fa0ff5dee9da54847694',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d5b8fa0ff5dee9da54847694',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'If U Need It',
#     'release_date': '2023-11-03',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:628CN0UzuPsstc678cQ5Sn'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1GuqTQbuixFHD6eBkFwVcb'},
#      'href': 'https://api.spotify.com/v1/artists/1GuqTQbuixFHD6eBkFwVcb',
#      'id': '1GuqTQbuixFHD6eBkFwVcb',
#      'name': 'Sammy Virji',
#      'type': 'artist',
#      'uri': 'spotify:artist:1GuqTQbuixFHD6eBkFwVcb'}],
#    'disc_number': 1,
#    'duration_ms': 179999,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBUM72309238'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5CaUUACiQFEf4zR5WoeIrp'},
#    'href': 'https://api.spotify.com/v1/tracks/5CaUUACiQFEf4zR5WoeIrp',
#    'id': '5CaUUACiQFEf4zR5WoeIrp',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'If U Need It',
#    'popularity': 63,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5CaUUACiQFEf4zR5WoeIrp'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-11-16T19:04:17Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yeahthejacko'},
#    'href': 'https://api.spotify.com/v1/users/yeahthejacko',
#    'id': 'yeahthejacko',
#    'type': 'user',
#    'uri': 'spotify:user:yeahthejacko'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ABBMkcUeM9hdpimo86mo6'},
#       'href': 'https://api.spotify.com/v1/artists/2ABBMkcUeM9hdpimo86mo6',
#       'id': '2ABBMkcUeM9hdpimo86mo6',
#       'name': 'Tourist',
#       'type': 'artist',
#       'uri': 'spotify:artist:2ABBMkcUeM9hdpimo86mo6'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0uTa7zuhN42yVclpAkJL9i'},
#     'href': 'https://api.spotify.com/v1/albums/0uTa7zuhN42yVclpAkJL9i',
#     'id': '0uTa7zuhN42yVclpAkJL9i',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273102aa1accc98b77af221a3df',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02102aa1accc98b77af221a3df',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851102aa1accc98b77af221a3df',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'EST',
#     'release_date': '2023-11-10',
#     'release_date_precision': 'day',
#     'total_tracks': 3,
#     'type': 'album',
#     'uri': 'spotify:album:0uTa7zuhN42yVclpAkJL9i'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ABBMkcUeM9hdpimo86mo6'},
#      'href': 'https://api.spotify.com/v1/artists/2ABBMkcUeM9hdpimo86mo6',
#      'id': '2ABBMkcUeM9hdpimo86mo6',
#      'name': 'Tourist',
#      'type': 'artist',
#      'uri': 'spotify:artist:2ABBMkcUeM9hdpimo86mo6'}],
#    'disc_number': 1,
#    'duration_ms': 336541,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMFME2370721'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1ojCQ0v59O77rKZbwN8aQh'},
#    'href': 'https://api.spotify.com/v1/tracks/1ojCQ0v59O77rKZbwN8aQh',
#    'id': '1ojCQ0v59O77rKZbwN8aQh',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'EST',
#    'popularity': 51,
#    'preview_url': 'https://p.scdn.co/mp3-preview/55296eed4c0844d7f7aef96f33a360f18a076cce?cid=d93283ae0ac74ebc9d1ecc472254bada',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1ojCQ0v59O77rKZbwN8aQh'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-11-16T19:04:17Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yeahthejacko'},
#    'href': 'https://api.spotify.com/v1/users/yeahthejacko',
#    'id': 'yeahthejacko',
#    'type': 'user',
#    'uri': 'spotify:user:yeahthejacko'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1R2O77qTPhGAIdRESKwc1J'},
#       'href': 'https://api.spotify.com/v1/artists/1R2O77qTPhGAIdRESKwc1J',
#       'id': '1R2O77qTPhGAIdRESKwc1J',
#       'name': '44 Ardent',
#       'type': 'artist',
#       'uri': 'spotify:artist:1R2O77qTPhGAIdRESKwc1J'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6mCduOVVaa6X4GrjII843z'},
#     'href': 'https://api.spotify.com/v1/albums/6mCduOVVaa6X4GrjII843z',
#     'id': '6mCduOVVaa6X4GrjII843z',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27323e0b4dd92798cd63112610b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0223e0b4dd92798cd63112610b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485123e0b4dd92798cd63112610b',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'onlyknow',
#     'release_date': '2023-11-07',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6mCduOVVaa6X4GrjII843z'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1R2O77qTPhGAIdRESKwc1J'},
#      'href': 'https://api.spotify.com/v1/artists/1R2O77qTPhGAIdRESKwc1J',
#      'id': '1R2O77qTPhGAIdRESKwc1J',
#      'name': '44 Ardent',
#      'type': 'artist',
#      'uri': 'spotify:artist:1R2O77qTPhGAIdRESKwc1J'}],
#    'disc_number': 1,
#    'duration_ms': 179333,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DGA0H2304585'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0Q7PR1J2BDz9VdONFGBJoU'},
#    'href': 'https://api.spotify.com/v1/tracks/0Q7PR1J2BDz9VdONFGBJoU',
#    'id': '0Q7PR1J2BDz9VdONFGBJoU',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'onlyknow',
#    'popularity': 20,
#    'preview_url': 'https://p.scdn.co/mp3-preview/52ad3a18ad6b51ae016d8dd00d225f73b018fe90?cid=d93283ae0ac74ebc9d1ecc472254bada',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0Q7PR1J2BDz9VdONFGBJoU'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-11-03T08:36:55Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yeahthejacko'},
#    'href': 'https://api.spotify.com/v1/users/yeahthejacko',
#    'id': 'yeahthejacko',
#    'type': 'user',
#    'uri': 'spotify:user:yeahthejacko'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1eWXBPrs5K5aZXTIWdIlPe'},
#       'href': 'https://api.spotify.com/v1/artists/1eWXBPrs5K5aZXTIWdIlPe',
#       'id': '1eWXBPrs5K5aZXTIWdIlPe',
#       'name': 'Dom Valentino',
#       'type': 'artist',
#       'uri': 'spotify:artist:1eWXBPrs5K5aZXTIWdIlPe'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6QzMY3tnu0m56eKUnr4uCF'},
#       'href': 'https://api.spotify.com/v1/artists/6QzMY3tnu0m56eKUnr4uCF',
#       'id': '6QzMY3tnu0m56eKUnr4uCF',
#       'name': 'Alfie Templeman',
#       'type': 'artist',
#       'uri': 'spotify:artist:6QzMY3tnu0m56eKUnr4uCF'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1mSJCvDX0W7Dn7S9C6vmvI'},
#       'href': 'https://api.spotify.com/v1/artists/1mSJCvDX0W7Dn7S9C6vmvI',
#       'id': '1mSJCvDX0W7Dn7S9C6vmvI',
#       'name': 'Anna of the North',
#       'type': 'artist',
#       'uri': 'spotify:artist:1mSJCvDX0W7Dn7S9C6vmvI'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1Wr3TqDX4bDzWELjH0kTE5'},
#     'href': 'https://api.spotify.com/v1/albums/1Wr3TqDX4bDzWELjH0kTE5',
#     'id': '1Wr3TqDX4bDzWELjH0kTE5',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273866d64fb64b0defa8414e55b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02866d64fb64b0defa8414e55b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851866d64fb64b0defa8414e55b',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Young Folks',
#     'release_date': '2023-10-27',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:1Wr3TqDX4bDzWELjH0kTE5'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1eWXBPrs5K5aZXTIWdIlPe'},
#      'href': 'https://api.spotify.com/v1/artists/1eWXBPrs5K5aZXTIWdIlPe',
#      'id': '1eWXBPrs5K5aZXTIWdIlPe',
#      'name': 'Dom Valentino',
#      'type': 'artist',
#      'uri': 'spotify:artist:1eWXBPrs5K5aZXTIWdIlPe'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6QzMY3tnu0m56eKUnr4uCF'},
#      'href': 'https://api.spotify.com/v1/artists/6QzMY3tnu0m56eKUnr4uCF',
#      'id': '6QzMY3tnu0m56eKUnr4uCF',
#      'name': 'Alfie Templeman',
#      'type': 'artist',
#      'uri': 'spotify:artist:6QzMY3tnu0m56eKUnr4uCF'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1mSJCvDX0W7Dn7S9C6vmvI'},
#      'href': 'https://api.spotify.com/v1/artists/1mSJCvDX0W7Dn7S9C6vmvI',
#      'id': '1mSJCvDX0W7Dn7S9C6vmvI',
#      'name': 'Anna of the North',
#      'type': 'artist',
#      'uri': 'spotify:artist:1mSJCvDX0W7Dn7S9C6vmvI'}],
#    'disc_number': 1,
#    'duration_ms': 249022,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBENL2303743'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0XMWc0qrKeJnRzzyMj9Q7D'},
#    'href': 'https://api.spotify.com/v1/tracks/0XMWc0qrKeJnRzzyMj9Q7D',
#    'id': '0XMWc0qrKeJnRzzyMj9Q7D',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Young Folks',
#    'popularity': 51,
#    'preview_url': 'https://p.scdn.co/mp3-preview/32c47b5eb456bb911d037b2fff1cf85f5f9656e9?cid=d93283ae0ac74ebc9d1ecc472254bada',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0XMWc0qrKeJnRzzyMj9Q7D'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-11-07T21:56:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yeahthejacko'},
#    'href': 'https://api.spotify.com/v1/users/yeahthejacko',
#    'id': 'yeahthejacko',
#    'type': 'user',
#    'uri': 'spotify:user:yeahthejacko'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6a5fdBQLjJqoSGN5gythKm'},
#       'href': 'https://api.spotify.com/v1/artists/6a5fdBQLjJqoSGN5gythKm',
#       'id': '6a5fdBQLjJqoSGN5gythKm',
#       'name': 'bad tuner',
#       'type': 'artist',
#       'uri': 'spotify:artist:6a5fdBQLjJqoSGN5gythKm'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2O3Z76ivO59CQ6F1SGbNsP'},
#     'href': 'https://api.spotify.com/v1/albums/2O3Z76ivO59CQ6F1SGbNsP',
#     'id': '2O3Z76ivO59CQ6F1SGbNsP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27353ef279703a17e03883dffe4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0253ef279703a17e03883dffe4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485153ef279703a17e03883dffe4',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'could i',
#     'release_date': '2023-11-03',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2O3Z76ivO59CQ6F1SGbNsP'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6a5fdBQLjJqoSGN5gythKm'},
#      'href': 'https://api.spotify.com/v1/artists/6a5fdBQLjJqoSGN5gythKm',
#      'id': '6a5fdBQLjJqoSGN5gythKm',
#      'name': 'bad tuner',
#      'type': 'artist',
#      'uri': 'spotify:artist:6a5fdBQLjJqoSGN5gythKm'}],
#    'disc_number': 1,
#    'duration_ms': 211000,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZTB72322116'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3PHuxF4HAHteJUSezfBRj2'},
#    'href': 'https://api.spotify.com/v1/tracks/3PHuxF4HAHteJUSezfBRj2',
#    'id': '3PHuxF4HAHteJUSezfBRj2',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'could i',
#    'popularity': 29,
#    'preview_url': 'https://p.scdn.co/mp3-preview/19276bf99ecd85131f352376b0a3854fbba992f4?cid=d93283ae0ac74ebc9d1ecc472254bada',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3PHuxF4HAHteJUSezfBRj2'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-11-07T21:56:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yeahthejacko'},
#    'href': 'https://api.spotify.com/v1/users/yeahthejacko',
#    'id': 'yeahthejacko',
#    'type': 'user',
#    'uri': 'spotify:user:yeahthejacko'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1MuDSnGT0IosRnJbulWvQn'},
#       'href': 'https://api.spotify.com/v1/artists/1MuDSnGT0IosRnJbulWvQn',
#       'id': '1MuDSnGT0IosRnJbulWvQn',
#       'name': 'Remedy Club',
#       'type': 'artist',
#       'uri': 'spotify:artist:1MuDSnGT0IosRnJbulWvQn'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6NGofnQORNQtnWXN3ef270'},
#       'href': 'https://api.spotify.com/v1/artists/6NGofnQORNQtnWXN3ef270',
#       'id': '6NGofnQORNQtnWXN3ef270',
#       'name': 'Charlie Boon',
#       'type': 'artist',
#       'uri': 'spotify:artist:6NGofnQORNQtnWXN3ef270'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/354PrxwnfTra1MVHXcmLLT'},
#     'href': 'https://api.spotify.com/v1/albums/354PrxwnfTra1MVHXcmLLT',
#     'id': '354PrxwnfTra1MVHXcmLLT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732ed40a7747cda09f142c108d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022ed40a7747cda09f142c108d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512ed40a7747cda09f142c108d',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Satellite',
#     'release_date': '2023-11-03',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:354PrxwnfTra1MVHXcmLLT'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1MuDSnGT0IosRnJbulWvQn'},
#      'href': 'https://api.spotify.com/v1/artists/1MuDSnGT0IosRnJbulWvQn',
#      'id': '1MuDSnGT0IosRnJbulWvQn',
#      'name': 'Remedy Club',
#      'type': 'artist',
#      'uri': 'spotify:artist:1MuDSnGT0IosRnJbulWvQn'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6NGofnQORNQtnWXN3ef270'},
#      'href': 'https://api.spotify.com/v1/artists/6NGofnQORNQtnWXN3ef270',
#      'id': '6NGofnQORNQtnWXN3ef270',
#      'name': 'Charlie Boon',
#      'type': 'artist',
#      'uri': 'spotify:artist:6NGofnQORNQtnWXN3ef270'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7MkgzUjbcypG4VqY3iAYuW'},
#      'href': 'https://api.spotify.com/v1/artists/7MkgzUjbcypG4VqY3iAYuW',
#      'id': '7MkgzUjbcypG4VqY3iAYuW',
#      'name': 'MELODIE',
#      'type': 'artist',
#      'uri': 'spotify:artist:7MkgzUjbcypG4VqY3iAYuW'}],
#    'disc_number': 1,
#    'duration_ms': 183678,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZS632319818'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1ka96CzPUdKdTyz1YqPQVG'},
#    'href': 'https://api.spotify.com/v1/tracks/1ka96CzPUdKdTyz1YqPQVG',
#    'id': '1ka96CzPUdKdTyz1YqPQVG',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Satellite',
#    'popularity': 36,
#    'preview_url': 'https://p.scdn.co/mp3-preview/14e1911f2190d009ed31d3b67eacc77f665bed54?cid=d93283ae0ac74ebc9d1ecc472254bada',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1ka96CzPUdKdTyz1YqPQVG'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-11-03T08:37:44Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yeahthejacko'},
#    'href': 'https://api.spotify.com/v1/users/yeahthejacko',
#    'id': 'yeahthejacko',
#    'type': 'user',
#    'uri': 'spotify:user:yeahthejacko'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3QRHP3Oley1iHSfR9geMp2'},
#       'href': 'https://api.spotify.com/v1/artists/3QRHP3Oley1iHSfR9geMp2',
#       'id': '3QRHP3Oley1iHSfR9geMp2',
#       'name': 'Tom Mckeen',
#       'type': 'artist',
#       'uri': 'spotify:artist:3QRHP3Oley1iHSfR9geMp2'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6PdwTFrJAApw5nQpIaOWex'},
#     'href': 'https://api.spotify.com/v1/albums/6PdwTFrJAApw5nQpIaOWex',
#     'id': '6PdwTFrJAApw5nQpIaOWex',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273067cc04d388d32c57fb054fc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02067cc04d388d32c57fb054fc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851067cc04d388d32c57fb054fc',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Mira',
#     'release_date': '2023-11-03',
#     'release_date_precision': 'day',
#     'total_tracks': 3,
#     'type': 'album',
#     'uri': 'spotify:album:6PdwTFrJAApw5nQpIaOWex'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3QRHP3Oley1iHSfR9geMp2'},
#      'href': 'https://api.spotify.com/v1/artists/3QRHP3Oley1iHSfR9geMp2',
#      'id': '3QRHP3Oley1iHSfR9geMp2',
#      'name': 'Tom Mckeen',
#      'type': 'artist',
#      'uri': 'spotify:artist:3QRHP3Oley1iHSfR9geMp2'}],
#    'disc_number': 1,
#    'duration_ms': 333548,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZK6J2360160'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3xNZZtpAzqx2Y29pgsxqo0'},
#    'href': 'https://api.spotify.com/v1/tracks/3xNZZtpAzqx2Y29pgsxqo0',
#    'id': '3xNZZtpAzqx2Y29pgsxqo0',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Mira',
#    'popularity': 20,
#    'preview_url': 'https://p.scdn.co/mp3-preview/9e766e6a311708c7732b1b77e5c1dc21e145f767?cid=d93283ae0ac74ebc9d1ecc472254bada',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3xNZZtpAzqx2Y29pgsxqo0'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-11-03T08:36:55Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yeahthejacko'},
#    'href': 'https://api.spotify.com/v1/users/yeahthejacko',
#    'id': 'yeahthejacko',
#    'type': 'user',
#    'uri': 'spotify:user:yeahthejacko'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0HHa7ZJZxUQlg5l2mB0N0f'},
#       'href': 'https://api.spotify.com/v1/artists/0HHa7ZJZxUQlg5l2mB0N0f',
#       'id': '0HHa7ZJZxUQlg5l2mB0N0f',
#       'name': 'Marlon Hoffstadt',
#       'type': 'artist',
#       'uri': 'spotify:artist:0HHa7ZJZxUQlg5l2mB0N0f'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4lBSzo2LS8asEzoePv6VLM'},
#       'href': 'https://api.spotify.com/v1/artists/4lBSzo2LS8asEzoePv6VLM',
#       'id': '4lBSzo2LS8asEzoePv6VLM',
#       'name': 'DJ Daddy Trance',
#       'type': 'artist',
#       'uri': 'spotify:artist:4lBSzo2LS8asEzoePv6VLM'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0h9Si8hhyqG2TRm61mNUnv'},
#     'href': 'https://api.spotify.com/v1/albums/0h9Si8hhyqG2TRm61mNUnv',
#     'id': '0h9Si8hhyqG2TRm61mNUnv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27366a26a2f6dbdf30978c6e77d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0266a26a2f6dbdf30978c6e77d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485166a26a2f6dbdf30978c6e77d',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'I Got You',
#     'release_date': '2023-11-03',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:0h9Si8hhyqG2TRm61mNUnv'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0HHa7ZJZxUQlg5l2mB0N0f'},
#      'href': 'https://api.spotify.com/v1/artists/0HHa7ZJZxUQlg5l2mB0N0f',
#      'id': '0HHa7ZJZxUQlg5l2mB0N0f',
#      'name': 'Marlon Hoffstadt',
#      'type': 'artist',
#      'uri': 'spotify:artist:0HHa7ZJZxUQlg5l2mB0N0f'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4lBSzo2LS8asEzoePv6VLM'},
#      'href': 'https://api.spotify.com/v1/artists/4lBSzo2LS8asEzoePv6VLM',
#      'id': '4lBSzo2LS8asEzoePv6VLM',
#      'name': 'DJ Daddy Trance',
#      'type': 'artist',
#      'uri': 'spotify:artist:4lBSzo2LS8asEzoePv6VLM'}],
#    'disc_number': 1,
#    'duration_ms': 164983,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZS7J2336760'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2FAik0wCT2bEcXMeYhoTkj'},
#    'href': 'https://api.spotify.com/v1/tracks/2FAik0wCT2bEcXMeYhoTkj',
#    'id': '2FAik0wCT2bEcXMeYhoTkj',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'I Got You',
#    'popularity': 63,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c07f0852fd600102a5e85a156069e51b4f56396a?cid=d93283ae0ac74ebc9d1ecc472254bada',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2FAik0wCT2bEcXMeYhoTkj'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-11-03T08:36:55Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yeahthejacko'},
#    'href': 'https://api.spotify.com/v1/users/yeahthejacko',
#    'id': 'yeahthejacko',
#    'type': 'user',
#    'uri': 'spotify:user:yeahthejacko'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ptklB4QBKqyRZNAkAEq8U'},
#       'href': 'https://api.spotify.com/v1/artists/2ptklB4QBKqyRZNAkAEq8U',
#       'id': '2ptklB4QBKqyRZNAkAEq8U',
#       'name': 'Rommii',
#       'type': 'artist',
#       'uri': 'spotify:artist:2ptklB4QBKqyRZNAkAEq8U'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/03nqonZ3inIazXypenyqLl'},
#     'href': 'https://api.spotify.com/v1/albums/03nqonZ3inIazXypenyqLl',
#     'id': '03nqonZ3inIazXypenyqLl',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738b3bac1e225afabaa9534003',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028b3bac1e225afabaa9534003',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518b3bac1e225afabaa9534003',
#       'width': 64}],
#     'is_playable': True,
#     'name': "thinkin' about you",
#     'release_date': '2023-07-28',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:03nqonZ3inIazXypenyqLl'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ptklB4QBKqyRZNAkAEq8U'},
#      'href': 'https://api.spotify.com/v1/artists/2ptklB4QBKqyRZNAkAEq8U',
#      'id': '2ptklB4QBKqyRZNAkAEq8U',
#      'name': 'Rommii',
#      'type': 'artist',
#      'uri': 'spotify:artist:2ptklB4QBKqyRZNAkAEq8U'}],
#    'disc_number': 1,
#    'duration_ms': 137872,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMBZ92301253'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5IRzClFKHGNfPhQFhKD2IP'},
#    'href': 'https://api.spotify.com/v1/tracks/5IRzClFKHGNfPhQFhKD2IP',
#    'id': '5IRzClFKHGNfPhQFhKD2IP',
#    'is_local': False,
#    'is_playable': True,
#    'name': "thinkin' about you",
#    'popularity': 45,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8090caca7c2d7c360fc5526d67a7ce2d90d44276?cid=d93283ae0ac74ebc9d1ecc472254bada',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5IRzClFKHGNfPhQFhKD2IP'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-11-03T08:36:55Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yeahthejacko'},
#    'href': 'https://api.spotify.com/v1/users/yeahthejacko',
#    'id': 'yeahthejacko',
#    'type': 'user',
#    'uri': 'spotify:user:yeahthejacko'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4SV6cezgr2EYpAUV7j8ABo'},
#       'href': 'https://api.spotify.com/v1/artists/4SV6cezgr2EYpAUV7j8ABo',
#       'id': '4SV6cezgr2EYpAUV7j8ABo',
#       'name': 'Little Fritter',
#       'type': 'artist',
#       'uri': 'spotify:artist:4SV6cezgr2EYpAUV7j8ABo'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7yx47vjNgvQXPtHis6Hi91'},
#       'href': 'https://api.spotify.com/v1/artists/7yx47vjNgvQXPtHis6Hi91',
#       'id': '7yx47vjNgvQXPtHis6Hi91',
#       'name': 'Wongo',
#       'type': 'artist',
#       'uri': 'spotify:artist:7yx47vjNgvQXPtHis6Hi91'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3s6gQyRQwVOMehnio4UTYC'},
#     'href': 'https://api.spotify.com/v1/albums/3s6gQyRQwVOMehnio4UTYC',
#     'id': '3s6gQyRQwVOMehnio4UTYC',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a3350e000ec2974a644f6ec3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a3350e000ec2974a644f6ec3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a3350e000ec2974a644f6ec3',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Real High / Let the Bass Go',
#     'release_date': '2023-10-19',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:3s6gQyRQwVOMehnio4UTYC'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4SV6cezgr2EYpAUV7j8ABo'},
#      'href': 'https://api.spotify.com/v1/artists/4SV6cezgr2EYpAUV7j8ABo',
#      'id': '4SV6cezgr2EYpAUV7j8ABo',
#      'name': 'Little Fritter',
#      'type': 'artist',
#      'uri': 'spotify:artist:4SV6cezgr2EYpAUV7j8ABo'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7yx47vjNgvQXPtHis6Hi91'},
#      'href': 'https://api.spotify.com/v1/artists/7yx47vjNgvQXPtHis6Hi91',
#      'id': '7yx47vjNgvQXPtHis6Hi91',
#      'name': 'Wongo',
#      'type': 'artist',
#      'uri': 'spotify:artist:7yx47vjNgvQXPtHis6Hi91'}],
#    'disc_number': 1,
#    'duration_ms': 199279,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'AUXN22383207'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5wnpLkYwuvWIll9tZkcgnN'},
#    'href': 'https://api.spotify.com/v1/tracks/5wnpLkYwuvWIll9tZkcgnN',
#    'id': '5wnpLkYwuvWIll9tZkcgnN',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Real High',
#    'popularity': 31,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ec4c04ea5adad05637cbfacd2ec71ab5a07c974c?cid=d93283ae0ac74ebc9d1ecc472254bada',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5wnpLkYwuvWIll9tZkcgnN'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-11-03T08:36:55Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yeahthejacko'},
#    'href': 'https://api.spotify.com/v1/users/yeahthejacko',
#    'id': 'yeahthejacko',
#    'type': 'user',
#    'uri': 'spotify:user:yeahthejacko'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3pK4EcflBpG1Kpmjk5LK2R'},
#       'href': 'https://api.spotify.com/v1/artists/3pK4EcflBpG1Kpmjk5LK2R',
#       'id': '3pK4EcflBpG1Kpmjk5LK2R',
#       'name': 'Joy Anonymous',
#       'type': 'artist',
#       'uri': 'spotify:artist:3pK4EcflBpG1Kpmjk5LK2R'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/757FRJv2zPA021rfTPK7hr'},
#     'href': 'https://api.spotify.com/v1/albums/757FRJv2zPA021rfTPK7hr',
#     'id': '757FRJv2zPA021rfTPK7hr',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d501b88b5e37be6d996c6830',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d501b88b5e37be6d996c6830',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d501b88b5e37be6d996c6830',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'JOY (Up The Street)',
#     'release_date': '2023-11-01',
#     'release_date_precision': 'day',
#     'total_tracks': 5,
#     'type': 'album',
#     'uri': 'spotify:album:757FRJv2zPA021rfTPK7hr'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3pK4EcflBpG1Kpmjk5LK2R'},
#      'href': 'https://api.spotify.com/v1/artists/3pK4EcflBpG1Kpmjk5LK2R',
#      'id': '3pK4EcflBpG1Kpmjk5LK2R',
#      'name': 'Joy Anonymous',
#      'type': 'artist',
#      'uri': 'spotify:artist:3pK4EcflBpG1Kpmjk5LK2R'}],
#    'disc_number': 1,
#    'duration_ms': 237979,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBUM72306643'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5PFSQQxlsdUrR63J31spMv'},
#    'href': 'https://api.spotify.com/v1/tracks/5PFSQQxlsdUrR63J31spMv',
#    'id': '5PFSQQxlsdUrR63J31spMv',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'JOY (Up The Street)',
#    'popularity': 46,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5PFSQQxlsdUrR63J31spMv'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-11-03T08:36:55Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yeahthejacko'},
#    'href': 'https://api.spotify.com/v1/users/yeahthejacko',
#    'id': 'yeahthejacko',
#    'type': 'user',
#    'uri': 'spotify:user:yeahthejacko'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6ZHeg2Op5ZkNppXbNLSglj'},
#       'href': 'https://api.spotify.com/v1/artists/6ZHeg2Op5ZkNppXbNLSglj',
#       'id': '6ZHeg2Op5ZkNppXbNLSglj',
#       'name': 'Willaris. K',
#       'type': 'artist',
#       'uri': 'spotify:artist:6ZHeg2Op5ZkNppXbNLSglj'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0DqR5aQYPz1s2M3YbycLMJ'},
#       'href': 'https://api.spotify.com/v1/artists/0DqR5aQYPz1s2M3YbycLMJ',
#       'id': '0DqR5aQYPz1s2M3YbycLMJ',
#       'name': 'jamesjamesjames',
#       'type': 'artist',
#       'uri': 'spotify:artist:0DqR5aQYPz1s2M3YbycLMJ'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2EXRjHAkrjSSXD1rnMHmjv'},
#     'href': 'https://api.spotify.com/v1/albums/2EXRjHAkrjSSXD1rnMHmjv',
#     'id': '2EXRjHAkrjSSXD1rnMHmjv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ead1d014f782631f83467ea9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ead1d014f782631f83467ea9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ead1d014f782631f83467ea9',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Silversun',
#     'release_date': '2023-10-25',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2EXRjHAkrjSSXD1rnMHmjv'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6ZHeg2Op5ZkNppXbNLSglj'},
#      'href': 'https://api.spotify.com/v1/artists/6ZHeg2Op5ZkNppXbNLSglj',
#      'id': '6ZHeg2Op5ZkNppXbNLSglj',
#      'name': 'Willaris. K',
#      'type': 'artist',
#      'uri': 'spotify:artist:6ZHeg2Op5ZkNppXbNLSglj'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0DqR5aQYPz1s2M3YbycLMJ'},
#      'href': 'https://api.spotify.com/v1/artists/0DqR5aQYPz1s2M3YbycLMJ',
#      'id': '0DqR5aQYPz1s2M3YbycLMJ',
#      'name': 'jamesjamesjames',
#      'type': 'artist',
#      'uri': 'spotify:artist:0DqR5aQYPz1s2M3YbycLMJ'}],
#    'disc_number': 1,
#    'duration_ms': 337884,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'AULI02354830'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1SmQp1FgwDVYh1GGlSUHEC'},
#    'href': 'https://api.spotify.com/v1/tracks/1SmQp1FgwDVYh1GGlSUHEC',
#    'id': '1SmQp1FgwDVYh1GGlSUHEC',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5Yki24QFYrkTiqtQIOmFq2'},
#     'href': 'https://api.spotify.com/v1/tracks/5Yki24QFYrkTiqtQIOmFq2',
#     'id': '5Yki24QFYrkTiqtQIOmFq2',
#     'type': 'track',
#     'uri': 'spotify:track:5Yki24QFYrkTiqtQIOmFq2'},
#    'name': 'Silversun',
#    'popularity': 39,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1SmQp1FgwDVYh1GGlSUHEC'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-11-03T08:36:55Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yeahthejacko'},
#    'href': 'https://api.spotify.com/v1/users/yeahthejacko',
#    'id': 'yeahthejacko',
#    'type': 'user',
#    'uri': 'spotify:user:yeahthejacko'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
# ...
#  {'added_at': '2023-06-24T09:59:53Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yeahthejacko'},
#    'href': 'https://api.spotify.com/v1/users/yeahthejacko',
#    'id': 'yeahthejacko',
#    'type': 'user',
#    'uri': 'spotify:user:yeahthejacko'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3MkIU5jhXTMK9pYQTRVI6p'},
#       'href': 'https://api.spotify.com/v1/artists/3MkIU5jhXTMK9pYQTRVI6p',
#       'id': '3MkIU5jhXTMK9pYQTRVI6p',
#       'name': 'DJ BORING',
#       'type': 'artist',
#       'uri': 'spotify:artist:3MkIU5jhXTMK9pYQTRVI6p'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5dtvpvsFIOwgBB85M3hxKR'},
#     'href': 'https://api.spotify.com/v1/albums/5dtvpvsFIOwgBB85M3hxKR',
#     'id': '5dtvpvsFIOwgBB85M3hxKR',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734f654220e981e6641a0d1383',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024f654220e981e6641a0d1383',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514f654220e981e6641a0d1383',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Beautiful Strangers',
#     'release_date': '2023-06-16',
#     'release_date_precision': 'day',
#     'total_tracks': 6,
#     'type': 'album',
#     'uri': 'spotify:album:5dtvpvsFIOwgBB85M3hxKR'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3MkIU5jhXTMK9pYQTRVI6p'},
#      'href': 'https://api.spotify.com/v1/artists/3MkIU5jhXTMK9pYQTRVI6p',
#      'id': '3MkIU5jhXTMK9pYQTRVI6p',
#      'name': 'DJ BORING',
#      'type': 'artist',
#      'uri': 'spotify:artist:3MkIU5jhXTMK9pYQTRVI6p'}],
#    'disc_number': 1,
#    'duration_ms': 325121,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DEVY92300129'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4UgstCyrgpaPLVVsf64sez'},
#    'href': 'https://api.spotify.com/v1/tracks/4UgstCyrgpaPLVVsf64sez',
#    'id': '4UgstCyrgpaPLVVsf64sez',
#    'is_local': False,
#    'is_playable': True,
#    'name': "Can't Fix A Broken Heart",
#    'popularity': 30,
#    'preview_url': 'https://p.scdn.co/mp3-preview/13dd21346fc4cc6babaf4e37bff1989a3ee0a6a4?cid=d93283ae0ac74ebc9d1ecc472254bada',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:4UgstCyrgpaPLVVsf64sez'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-06-24T10:00:22Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yeahthejacko'},
#    'href': 'https://api.spotify.com/v1/users/yeahthejacko',
#    'id': 'yeahthejacko',
#    'type': 'user',
#    'uri': 'spotify:user:yeahthejacko'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1np8xozf7ATJZDi9JX8Dx5'},
#       'href': 'https://api.spotify.com/v1/artists/1np8xozf7ATJZDi9JX8Dx5',
#       'id': '1np8xozf7ATJZDi9JX8Dx5',
#       'name': 'salute',
#       'type': 'artist',
#       'uri': 'spotify:artist:1np8xozf7ATJZDi9JX8Dx5'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7r2DO2kRoV44v9hdfgAQKr'},
#     'href': 'https://api.spotify.com/v1/albums/7r2DO2kRoV44v9hdfgAQKr',
#     'id': '7r2DO2kRoV44v9hdfgAQKr',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739dca4e89da488f29d87dfce0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029dca4e89da488f29d87dfce0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519dca4e89da488f29d87dfce0',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Shield',
#     'release_date': '2023-05-05',
#     'release_date_precision': 'day',
#     'total_tracks': 4,
#     'type': 'album',
#     'uri': 'spotify:album:7r2DO2kRoV44v9hdfgAQKr'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1np8xozf7ATJZDi9JX8Dx5'},
#      'href': 'https://api.spotify.com/v1/artists/1np8xozf7ATJZDi9JX8Dx5',
#      'id': '1np8xozf7ATJZDi9JX8Dx5',
#      'name': 'salute',
#      'type': 'artist',
#      'uri': 'spotify:artist:1np8xozf7ATJZDi9JX8Dx5'}],
#    'disc_number': 1,
#    'duration_ms': 208482,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBCFB2300165'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4WUYv43gJtAAIaeSBml8ow'},
#    'href': 'https://api.spotify.com/v1/tracks/4WUYv43gJtAAIaeSBml8ow',
#    'id': '4WUYv43gJtAAIaeSBml8ow',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Feels Like My Hands Are On Fire',
#    'popularity': 40,
#    'preview_url': 'https://p.scdn.co/mp3-preview/e56641f0bb05cc40eb7d72ea9707b1e8944acabb?cid=d93283ae0ac74ebc9d1ecc472254bada',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:4WUYv43gJtAAIaeSBml8ow'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-06-24T10:00:37Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yeahthejacko'},
#    'href': 'https://api.spotify.com/v1/users/yeahthejacko',
#    'id': 'yeahthejacko',
#    'type': 'user',
#    'uri': 'spotify:user:yeahthejacko'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3MkIU5jhXTMK9pYQTRVI6p'},
#       'href': 'https://api.spotify.com/v1/artists/3MkIU5jhXTMK9pYQTRVI6p',
#       'id': '3MkIU5jhXTMK9pYQTRVI6p',
#       'name': 'DJ BORING',
#       'type': 'artist',
#       'uri': 'spotify:artist:3MkIU5jhXTMK9pYQTRVI6p'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/188fPxDRvpLMpq3q9a0geW'},
#     'href': 'https://api.spotify.com/v1/albums/188fPxDRvpLMpq3q9a0geW',
#     'id': '188fPxDRvpLMpq3q9a0geW',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273155f05514526775998062242',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02155f05514526775998062242',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851155f05514526775998062242',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Beautiful Strangers',
#     'release_date': '2023-05-24',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:188fPxDRvpLMpq3q9a0geW'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3MkIU5jhXTMK9pYQTRVI6p'},
#      'href': 'https://api.spotify.com/v1/artists/3MkIU5jhXTMK9pYQTRVI6p',
#      'id': '3MkIU5jhXTMK9pYQTRVI6p',
#      'name': 'DJ BORING',
#      'type': 'artist',
#      'uri': 'spotify:artist:3MkIU5jhXTMK9pYQTRVI6p'}],
#    'disc_number': 1,
#    'duration_ms': 237027,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DEVY92300133'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5Un6I8vHv1x0HdWEXjOgwc'},
#    'href': 'https://api.spotify.com/v1/tracks/5Un6I8vHv1x0HdWEXjOgwc',
#    'id': '5Un6I8vHv1x0HdWEXjOgwc',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Beautiful Strangers',
#    'popularity': 44,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a74161e711c05ebe6fd6e8bd6fac99350b4cbf9a?cid=d93283ae0ac74ebc9d1ecc472254bada',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5Un6I8vHv1x0HdWEXjOgwc'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-06-24T10:00:48Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yeahthejacko'},
#    'href': 'https://api.spotify.com/v1/users/yeahthejacko',
#    'id': 'yeahthejacko',
#    'type': 'user',
#    'uri': 'spotify:user:yeahthejacko'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7LqcxF2CAiCymAsy9bCzFc'},
#       'href': 'https://api.spotify.com/v1/artists/7LqcxF2CAiCymAsy9bCzFc',
#       'id': '7LqcxF2CAiCymAsy9bCzFc',
#       'name': 'Glimji',
#       'type': 'artist',
#       'uri': 'spotify:artist:7LqcxF2CAiCymAsy9bCzFc'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2FEono1vla7gHmopKAAmjC'},
#     'href': 'https://api.spotify.com/v1/albums/2FEono1vla7gHmopKAAmjC',
#     'id': '2FEono1vla7gHmopKAAmjC',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27311b66f91d3001424210bde4c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0211b66f91d3001424210bde4c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485111b66f91d3001424210bde4c',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Flicker',
#     'release_date': '2023-06-07',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2FEono1vla7gHmopKAAmjC'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7LqcxF2CAiCymAsy9bCzFc'},
#      'href': 'https://api.spotify.com/v1/artists/7LqcxF2CAiCymAsy9bCzFc',
#      'id': '7LqcxF2CAiCymAsy9bCzFc',
#      'name': 'Glimji',
#      'type': 'artist',
#      'uri': 'spotify:artist:7LqcxF2CAiCymAsy9bCzFc'}],
#    'disc_number': 1,
#    'duration_ms': 186231,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QM6P42303561'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/147QfD9wJR5ztI6SpfBj1G'},
#    'href': 'https://api.spotify.com/v1/tracks/147QfD9wJR5ztI6SpfBj1G',
#    'id': '147QfD9wJR5ztI6SpfBj1G',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Flicker',
#    'popularity': 30,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f36b675300e51a9e3c7bd56bca1fa7665a77903b?cid=d93283ae0ac74ebc9d1ecc472254bada',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:147QfD9wJR5ztI6SpfBj1G'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-07-08T10:19:40Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yeahthejacko'},
#    'href': 'https://api.spotify.com/v1/users/yeahthejacko',
#    'id': 'yeahthejacko',
#    'type': 'user',
#    'uri': 'spotify:user:yeahthejacko'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7LqcxF2CAiCymAsy9bCzFc'},
#       'href': 'https://api.spotify.com/v1/artists/7LqcxF2CAiCymAsy9bCzFc',
#       'id': '7LqcxF2CAiCymAsy9bCzFc',
#       'name': 'Glimji',
#       'type': 'artist',
#       'uri': 'spotify:artist:7LqcxF2CAiCymAsy9bCzFc'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4m93u43UW24ySBeCPWDRQk'},
#     'href': 'https://api.spotify.com/v1/albums/4m93u43UW24ySBeCPWDRQk',
#     'id': '4m93u43UW24ySBeCPWDRQk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736ec23c8a2e080f7d164a33f0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026ec23c8a2e080f7d164a33f0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516ec23c8a2e080f7d164a33f0',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Sweetpea',
#     'release_date': '2022-11-09',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:4m93u43UW24ySBeCPWDRQk'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7LqcxF2CAiCymAsy9bCzFc'},
#      'href': 'https://api.spotify.com/v1/artists/7LqcxF2CAiCymAsy9bCzFc',
#      'id': '7LqcxF2CAiCymAsy9bCzFc',
#      'name': 'Glimji',
#      'type': 'artist',
#      'uri': 'spotify:artist:7LqcxF2CAiCymAsy9bCzFc'}],
#    'disc_number': 1,
#    'duration_ms': 209777,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMDA62275199'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3jx6OuHForSbsX62V5Dr39'},
#    'href': 'https://api.spotify.com/v1/tracks/3jx6OuHForSbsX62V5Dr39',
#    'id': '3jx6OuHForSbsX62V5Dr39',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Sweetpea',
#    'popularity': 24,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b55504c26a88994ebfade305c4200bc0c220f76f?cid=d93283ae0ac74ebc9d1ecc472254bada',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3jx6OuHForSbsX62V5Dr39'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2023-09-19T22:57:37Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/yeahthejacko'},
#    'href': 'https://api.spotify.com/v1/users/yeahthejacko',
#    'id': 'yeahthejacko',
#    'type': 'user',
#    'uri': 'spotify:user:yeahthejacko'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7nrVhzPUJsigF7rt9BL9jQ'},
#       'href': 'https://api.spotify.com/v1/artists/7nrVhzPUJsigF7rt9BL9jQ',
#       'id': '7nrVhzPUJsigF7rt9BL9jQ',
#       'name': '4am Kru',
#       'type': 'artist',
#       'uri': 'spotify:artist:7nrVhzPUJsigF7rt9BL9jQ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2Ppde9KaDEpnZuaEAlELO3'},
#       'href': 'https://api.spotify.com/v1/artists/2Ppde9KaDEpnZuaEAlELO3',
#       'id': '2Ppde9KaDEpnZuaEAlELO3',
#       'name': 'McDonald & Jannetta',
#       'type': 'artist',
#       'uri': 'spotify:artist:2Ppde9KaDEpnZuaEAlELO3'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3dO9tnx39lLoWZCHIWVszf'},
#     'href': 'https://api.spotify.com/v1/albums/3dO9tnx39lLoWZCHIWVszf',
#     'id': '3dO9tnx39lLoWZCHIWVszf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735813ae5a65d4cac75357f1f2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025813ae5a65d4cac75357f1f2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515813ae5a65d4cac75357f1f2',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Pianos Raining Down',
#     'release_date': '2022-10-28',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3dO9tnx39lLoWZCHIWVszf'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7nrVhzPUJsigF7rt9BL9jQ'},
#      'href': 'https://api.spotify.com/v1/artists/7nrVhzPUJsigF7rt9BL9jQ',
#      'id': '7nrVhzPUJsigF7rt9BL9jQ',
#      'name': '4am Kru',
#      'type': 'artist',
#      'uri': 'spotify:artist:7nrVhzPUJsigF7rt9BL9jQ'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2Ppde9KaDEpnZuaEAlELO3'},
#      'href': 'https://api.spotify.com/v1/artists/2Ppde9KaDEpnZuaEAlELO3',
#      'id': '2Ppde9KaDEpnZuaEAlELO3',
#      'name': 'McDonald & Jannetta',
#      'type': 'artist',
#      'uri': 'spotify:artist:2Ppde9KaDEpnZuaEAlELO3'}],
#    'disc_number': 1,
#    'duration_ms': 215728,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBKQU2252560'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5tUlvCKbV6xyAI7MgFuB0p'},
#    'href': 'https://api.spotify.com/v1/tracks/5tUlvCKbV6xyAI7MgFuB0p',
#    'id': '5tUlvCKbV6xyAI7MgFuB0p',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5SaVTrUTi3uKLfoaKlrGCx'},
#     'href': 'https://api.spotify.com/v1/tracks/5SaVTrUTi3uKLfoaKlrGCx',
#     'id': '5SaVTrUTi3uKLfoaKlrGCx',
#     'type': 'track',
#     'uri': 'spotify:track:5SaVTrUTi3uKLfoaKlrGCx'},
#    'name': 'Pianos Raining Down',
#    'popularity': 40,
#    'preview_url': 'https://p.scdn.co/mp3-preview/42732b7902431c2b89fe905caf8dc53d82c08b76?cid=d93283ae0ac74ebc9d1ecc472254bada',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5tUlvCKbV6xyAI7MgFuB0p'},
#   'video_thumbnail': {'url': None}}]

# %%
chill_ids =[]
for i in chill_p:
    chill_ids.append(i['track']['id'])

# %%
chill_af = []
for i in chill_ids:
    chill_af.append(sp.audio_features(i)[0])

# %%
df = pd.DataFrame(chill_af)

# %% [markdown]
# chunk_size = 100
# bp_ids_chopped = [bp_ids[i:i+chunk_size] for i in range(0,len(bp_ids), 100)]
# len(bp_ids_chopped)
#
# bp_ids_chopped

# %%
df.to_csv("out.csv")

# %% [markdown]
# ## Playlist 2

# %%
chill_p1 = get_playlist_tracks('Spotify','0C67u7PwsOe8fzBfczxlIZ')

chill1_ids =[]
for i in chill_p1:
    chill1_ids.append(i['track']['id'])
    
chill1_af = []
for i in chill1_ids:
    chill1_af.append(sp.audio_features(i)[0])
    
df1 = pd.DataFrame(chill1_af)

# %%
dff = pd.concat([df, df1], ignore_index = True)

# %%
dff.to_csv("out.csv")

# %%
dff
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.618   0.806    7    -5.308     1       0.0317      0.017900
# 1           0.706   0.863    4    -6.386     0       0.0475      0.013100
# 2           0.792   0.919    6    -9.028     0       0.0819      0.137000
# 3           0.684   0.997    8    -5.538     1       0.0579      0.002550
# 4           0.594   0.767    5    -3.706     1       0.3710      0.001520
# ..            ...     ...  ...       ...   ...          ...           ...
# 361         0.802   0.903   11    -3.267     0       0.0460      0.001100
# 362         0.414   0.853   11    -4.198     1       0.0453      0.018100
# 363         0.815   0.605    5    -9.118     0       0.0368      0.033000
# 364         0.734   0.735    7    -6.201     1       0.0650      0.000813
# 365         0.284   0.875   11    -6.069     0       0.0422      0.007520
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.776000     0.181    0.222  140.009  audio_features
# 1            0.834000     0.119    0.309  142.007  audio_features
# 2            0.151000     0.274    0.711  128.968  audio_features
# 3            0.779000     0.253    0.514  142.010  audio_features
# 4            0.000085     0.346    0.717  129.955  audio_features
# ..                ...       ...      ...      ...             ...
# 361          0.000000     0.173    0.960  128.930  audio_features
# 362          0.001200     0.049    0.624   93.770  audio_features
# 363          0.684000     0.114    0.795  102.642  audio_features
# 364          0.000032     0.559    0.729   96.806  audio_features
# 365          0.000461     0.402    0.595   75.009  audio_features
#
#                          id                                   uri  \
# 0    4YCVbp6suJ2Ayk9EtWQJuR  spotify:track:4YCVbp6suJ2Ayk9EtWQJuR
# 1    2HhhhHfVEmz09NAb0FxgDW  spotify:track:2HhhhHfVEmz09NAb0FxgDW
# 2    5qKuF0NtvWVn5UarAgyli3  spotify:track:5qKuF0NtvWVn5UarAgyli3
# 3    0lIOamNC6EMXu1AgPyzSTD  spotify:track:0lIOamNC6EMXu1AgPyzSTD
# 4    0LKAbdXTieXQrjuImr9B9u  spotify:track:0LKAbdXTieXQrjuImr9B9u
# ..                      ...                                   ...
# 361  02jcEwywffn3Tsb48fXmlW  spotify:track:02jcEwywffn3Tsb48fXmlW
# 362  5huLMzIzFEdVcvEzt2hfk1  spotify:track:5huLMzIzFEdVcvEzt2hfk1
# 363  3UBItNVbFQiVC5hBQlBvnr  spotify:track:3UBItNVbFQiVC5hBQlBvnr
# 364  0eO8MW9YSTK3CjdaTYKlhF  spotify:track:0eO8MW9YSTK3CjdaTYKlhF
# 365  1L94M3KIu7QluZe63g64rv  spotify:track:1L94M3KIu7QluZe63g64rv
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/4YCVbp6suJ2A...
# 1    https://api.spotify.com/v1/tracks/2HhhhHfVEmz0...
# 2    https://api.spotify.com/v1/tracks/5qKuF0NtvWVn...
# 3    https://api.spotify.com/v1/tracks/0lIOamNC6EMX...
# 4    https://api.spotify.com/v1/tracks/0LKAbdXTieXQ...
# ..                                                 ...
# 361  https://api.spotify.com/v1/tracks/02jcEwywffn3...
# 362  https://api.spotify.com/v1/tracks/5huLMzIzFEdV...
# 363  https://api.spotify.com/v1/tracks/3UBItNVbFQiV...
# 364  https://api.spotify.com/v1/tracks/0eO8MW9YSTK3...
# 365  https://api.spotify.com/v1/tracks/1L94M3KIu7Ql...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/4YCV...       259849
# 1    https://api.spotify.com/v1/audio-analysis/2Hhh...       230074
# 2    https://api.spotify.com/v1/audio-analysis/5qKu...       186625
# 3    https://api.spotify.com/v1/audio-analysis/0lIO...       299387
# 4    https://api.spotify.com/v1/audio-analysis/0LKA...       140538
# ..                                                 ...          ...
# 361  https://api.spotify.com/v1/audio-analysis/02jc...       192533
# 362  https://api.spotify.com/v1/audio-analysis/5huL...       171693
# 363  https://api.spotify.com/v1/audio-analysis/3UBI...       259893
# 364  https://api.spotify.com/v1/audio-analysis/0eO8...       246200
# 365  https://api.spotify.com/v1/audio-analysis/1L94...       340907
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 361               4
# 362               4
# 363               4
# 364               4
# 365               4
#
# [366 rows x 18 columns]

# %%
import pandas as pd
import random
import difflib
from sklearn import datasets # sklearn comes with some toy datasets to practice
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score
import spotipy
import numpy as np
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials

# %%
dff = pd.read_csv("out.csv")
df_features = pd.DataFrame(dff[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']])
df_features
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.618   0.806    7    -5.308     1       0.0317      0.017900
# 1           0.706   0.863    4    -6.386     0       0.0475      0.013100
# 2           0.792   0.919    6    -9.028     0       0.0819      0.137000
# 3           0.684   0.997    8    -5.538     1       0.0579      0.002550
# 4           0.594   0.767    5    -3.706     1       0.3710      0.001520
# ..            ...     ...  ...       ...   ...          ...           ...
# 361         0.802   0.903   11    -3.267     0       0.0460      0.001100
# 362         0.414   0.853   11    -4.198     1       0.0453      0.018100
# 363         0.815   0.605    5    -9.118     0       0.0368      0.033000
# 364         0.734   0.735    7    -6.201     1       0.0650      0.000813
# 365         0.284   0.875   11    -6.069     0       0.0422      0.007520
#
#      instrumentalness  liveness  valence    tempo
# 0            0.776000     0.181    0.222  140.009
# 1            0.834000     0.119    0.309  142.007
# 2            0.151000     0.274    0.711  128.968
# 3            0.779000     0.253    0.514  142.010
# 4            0.000085     0.346    0.717  129.955
# ..                ...       ...      ...      ...
# 361          0.000000     0.173    0.960  128.930
# 362          0.001200     0.049    0.624   93.770
# 363          0.684000     0.114    0.795  102.642
# 364          0.000032     0.559    0.729   96.806
# 365          0.000461     0.402    0.595   75.009
#
# [366 rows x 11 columns]

# %%
df_features.describe()
# Out:
#        danceability      energy         key    loudness        mode  \
# count    366.000000  366.000000  366.000000  366.000000  366.000000
# mean       0.647896    0.774898    5.579235   -7.128227    0.609290
# std        0.132430    0.167543    3.710482    2.510177    0.488578
# min        0.284000    0.089800    0.000000  -17.876000    0.000000
# 25%        0.565250    0.664250    2.000000   -8.286000    0.000000
# 50%        0.662000    0.820000    6.000000   -6.754000    1.000000
# 75%        0.741750    0.904750    9.000000   -5.559250    1.000000
# max        0.949000    0.997000   11.000000   -0.504000    1.000000
#
#        speechiness  acousticness  instrumentalness    liveness     valence  \
# count   366.000000    366.000000        366.000000  366.000000  366.000000
# mean      0.073021      0.122163          0.240160    0.184603    0.561647
# std       0.088097      0.182227          0.341557    0.142827    0.255846
# min       0.023500      0.000025          0.000000    0.017600    0.043800
# 25%       0.035350      0.006513          0.000004    0.091750    0.358250
# 50%       0.045800      0.038250          0.003855    0.124000    0.596500
# 75%       0.071525      0.160750          0.582250    0.251750    0.776000
# max       0.911000      0.951000          0.937000    0.868000    0.975000
#
#             tempo
# count  366.000000
# mean   123.841893
# std     24.204608
# min     67.531000
# 25%    103.741500
# 50%    128.795500
# 75%    139.948750
# max    201.936000

# %%
scaler = StandardScaler()
scaler.fit(df_features)
features_scaled = scaler.transform(df_features)
features_scaled_df = pd.DataFrame(features_scaled, columns = df_features.columns)
#display(X.head())
print()
display(features_scaled_df)
# Out:
#      danceability    energy       key  loudness      mode  speechiness  \
# 0       -0.226059  0.185888  0.383430  0.726131  0.800784    -0.469685
# 1        0.439351  0.526565 -0.426197  0.296092 -1.248776    -0.290091
# 2        1.089638  0.861264  0.113554 -0.757864 -1.248776     0.100925
# 3        0.272998  1.327454  0.653306  0.634379  0.800784    -0.171877
# 4       -0.407535 -0.047207 -0.156321  1.365207  0.800784     3.387045
# ..            ...       ...       ...       ...       ...          ...
# 361      1.165252  0.765636  1.462933  1.540334 -1.248776    -0.307141
# 362     -1.768600  0.466797  1.462933  1.168936  0.800784    -0.315097
# 363      1.263552 -1.015446 -0.156321 -0.793767 -1.248776    -0.411715
# 364      0.651072 -0.238464  0.383430  0.369893  0.800784    -0.091173
# 365     -2.751592  0.598286  1.462933  0.422551 -1.248776    -0.350334
#
#      acousticness  instrumentalness  liveness   valence     tempo
# 0       -0.572942          1.570963 -0.025259 -1.329359  0.668849
# 1       -0.599319          1.741006 -0.459945 -0.988846  0.751509
# 2        0.081532         -0.261399  0.626770  0.584559  0.212072
# 3       -0.657293          1.579758  0.479538 -0.186488  0.751633
# 4       -0.662953         -0.703849  1.131567  0.608043  0.252905
# ..            ...               ...       ...       ...       ...
# 361     -0.665261         -0.704097 -0.081348  1.559132  0.210500
# 362     -0.571843         -0.700579 -0.950720  0.244046 -1.244104
# 363     -0.489965          1.301239 -0.495000  0.913331 -0.877061
# 364     -0.666838         -0.704002  2.624924  0.655010 -1.118502
# 365     -0.629982         -0.702746  1.524187  0.130542 -2.020266
#
# [366 rows x 11 columns]

# %%
kmeans = KMeans(n_clusters=6, random_state=1234)
kmeans.fit(features_scaled_df)
# Out:
# C:\Users\41791\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\41791\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# KMeans(n_clusters=6, random_state=1234)

# %%
labels = kmeans.labels_
labels
# Out:
# array([2, 2, 5, 2, 3, 5, 2, 2, 3, 5, 0, 4, 5, 2, 2, 5, 2, 2, 2, 2, 5, 5,
#        2, 0, 2, 0, 2, 2, 4, 3, 0, 2, 5, 2, 2, 2, 0, 4, 5, 2, 3, 2, 3, 0,
#        3, 2, 0, 5, 2, 2, 2, 3, 2, 2, 3, 2, 2, 2, 2, 2, 0, 4, 3, 5, 2, 2,
#        5, 5, 3, 4, 2, 5, 5, 2, 2, 2, 5, 2, 2, 2, 2, 3, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 3, 2, 2, 5, 2, 2, 3, 5, 2, 3, 5, 2, 0, 2, 2,
#        2, 2, 2, 0, 2, 3, 2, 2, 5, 2, 2, 2, 2, 2, 2, 2, 2, 3, 0, 2, 2, 2,
#        2, 2, 3, 3, 2, 3, 2, 0, 3, 5, 2, 5, 3, 2, 5, 3, 2, 2, 2, 4, 2, 2,
#        0, 2, 3, 3, 0, 5, 5, 5, 3, 3, 3, 3, 3, 2, 5, 4, 3, 3, 0, 4, 4, 4,
#        4, 0, 4, 4, 0, 3, 5, 5, 3, 5, 0, 4, 5, 5, 5, 3, 3, 5, 0, 5, 3, 0,
#        4, 4, 5, 0, 5, 4, 4, 3, 0, 3, 3, 0, 4, 4, 0, 3, 4, 3, 3, 3, 4, 5,
#        5, 4, 0, 4, 3, 4, 4, 3, 3, 0, 3, 0, 3, 3, 4, 5, 3, 3, 3, 5, 0, 5,
#        3, 5, 5, 4, 3, 5, 5, 5, 5, 4, 3, 3, 4, 5, 5, 4, 4, 3, 4, 4, 4, 4,
#        4, 3, 3, 5, 4, 5, 5, 3, 3, 5, 4, 3, 3, 2, 5, 3, 5, 3, 5, 5, 3, 3,
#        3, 5, 3, 3, 5, 3, 3, 5, 3, 3, 0, 3, 3, 3, 1, 4, 5, 3, 3, 0, 0, 3,
#        3, 4, 0, 3, 4, 3, 5, 3, 3, 5, 4, 3, 5, 3, 4, 3, 0, 3, 5, 5, 3, 3,
#        4, 4, 5, 3, 4, 4, 0, 0, 4, 0, 3, 4, 3, 4, 4, 4, 3, 5, 3, 5, 3, 3,
#        0, 2, 3, 3, 2, 1, 5, 3, 5, 5, 3, 5, 3, 5])

# %%
clusters = kmeans.predict(features_scaled_df)
#clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0     37
# 1      2
# 2     96
# 3    103
# 4     53
# 5     75
# Name: count, dtype: int64

# %%
clusters
# Out:
# array([2, 2, 5, 2, 3, 5, 2, 2, 3, 5, 0, 4, 5, 2, 2, 5, 2, 2, 2, 2, 5, 5,
#        2, 0, 2, 0, 2, 2, 4, 3, 0, 2, 5, 2, 2, 2, 0, 4, 5, 2, 3, 2, 3, 0,
#        3, 2, 0, 5, 2, 2, 2, 3, 2, 2, 3, 2, 2, 2, 2, 2, 0, 4, 3, 5, 2, 2,
#        5, 5, 3, 4, 2, 5, 5, 2, 2, 2, 5, 2, 2, 2, 2, 3, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 3, 2, 2, 5, 2, 2, 3, 5, 2, 3, 5, 2, 0, 2, 2,
#        2, 2, 2, 0, 2, 3, 2, 2, 5, 2, 2, 2, 2, 2, 2, 2, 2, 3, 0, 2, 2, 2,
#        2, 2, 3, 3, 2, 3, 2, 0, 3, 5, 2, 5, 3, 2, 5, 3, 2, 2, 2, 4, 2, 2,
#        0, 2, 3, 3, 0, 5, 5, 5, 3, 3, 3, 3, 3, 2, 5, 4, 3, 3, 0, 4, 4, 4,
#        4, 0, 4, 4, 0, 3, 5, 5, 3, 5, 0, 4, 5, 5, 5, 3, 3, 5, 0, 5, 3, 0,
#        4, 4, 5, 0, 5, 4, 4, 3, 0, 3, 3, 0, 4, 4, 0, 3, 4, 3, 3, 3, 4, 5,
#        5, 4, 0, 4, 3, 4, 4, 3, 3, 0, 3, 0, 3, 3, 4, 5, 3, 3, 3, 5, 0, 5,
#        3, 5, 5, 4, 3, 5, 5, 5, 5, 4, 3, 3, 4, 5, 5, 4, 4, 3, 4, 4, 4, 4,
#        4, 3, 3, 5, 4, 5, 5, 3, 3, 5, 4, 3, 3, 2, 5, 3, 5, 3, 5, 5, 3, 3,
#        3, 5, 3, 3, 5, 3, 3, 5, 3, 3, 0, 3, 3, 3, 1, 4, 5, 3, 3, 0, 0, 3,
#        3, 4, 0, 3, 4, 3, 5, 3, 3, 5, 4, 3, 5, 3, 4, 3, 0, 3, 5, 5, 3, 3,
#        4, 4, 5, 3, 4, 4, 0, 0, 4, 0, 3, 4, 3, 4, 4, 4, 3, 5, 3, 5, 3, 3,
#        0, 2, 3, 3, 2, 1, 5, 3, 5, 5, 3, 5, 3, 5])

# %%
df_features["cluster"] = clusters
df_features
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.618   0.806    7    -5.308     1       0.0317      0.017900
# 1           0.706   0.863    4    -6.386     0       0.0475      0.013100
# 2           0.792   0.919    6    -9.028     0       0.0819      0.137000
# 3           0.684   0.997    8    -5.538     1       0.0579      0.002550
# 4           0.594   0.767    5    -3.706     1       0.3710      0.001520
# ..            ...     ...  ...       ...   ...          ...           ...
# 361         0.802   0.903   11    -3.267     0       0.0460      0.001100
# 362         0.414   0.853   11    -4.198     1       0.0453      0.018100
# 363         0.815   0.605    5    -9.118     0       0.0368      0.033000
# 364         0.734   0.735    7    -6.201     1       0.0650      0.000813
# 365         0.284   0.875   11    -6.069     0       0.0422      0.007520
#
#      instrumentalness  liveness  valence    tempo  cluster
# 0            0.776000     0.181    0.222  140.009        2
# 1            0.834000     0.119    0.309  142.007        2
# 2            0.151000     0.274    0.711  128.968        5
# 3            0.779000     0.253    0.514  142.010        2
# 4            0.000085     0.346    0.717  129.955        3
# ..                ...       ...      ...      ...      ...
# 361          0.000000     0.173    0.960  128.930        5
# 362          0.001200     0.049    0.624   93.770        3
# 363          0.684000     0.114    0.795  102.642        5
# 364          0.000032     0.559    0.729   96.806        3
# 365          0.000461     0.402    0.595   75.009        5
#
# [366 rows x 12 columns]

# %%
top_100 = pd.read_csv("top_100.csv")
top_100
# Out:
#     Unnamed: 0                                              Title  \
# 0            0                                       Cruel Summer
# 1            1                                 Paint The Town Red
# 2            2  Is It Over Now? (Taylor's Version) [From The V...
# 3            3                                             Snooze
# 4            4                               Standing Next To You
# ..         ...                                                ...
# 95          95                           Clean (Taylor's Version)
# 96          96                                              Bleed
# 97          97                        But I Got A Beer In My Hand
# 98          98                             We Don't Fight Anymore
# 99          99                                      Sarah's Place
#
#                                     Artist
# 0                             Taylor Swift
# 1                                 Doja Cat
# 2                             Taylor Swift
# 3                                      SZA
# 4                                Jung Kook
# ..                                     ...
# 95                            Taylor Swift
# 96                           The Kid LAROI
# 97                              Luke Bryan
# 98  Carly Pearce Featuring Chris Stapleton
# 99         Zach Bryan Featuring Noah Kahan
#
# [100 rows x 3 columns]

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import config


#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
def play_song(track_id):
    return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %%
from IPython.display import IFrame

# %%
results_for_users= sp.search (q=user_input)
track_id= results_for_users ["tracks"]["items"][0]["id"]
print(track_id)
display(play_song (track_id))
# Out:
# 3CXrCYDz7R0vm7M6HR0DTY
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/3CXrCYDz7R0vm7M6HR0DTY?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Getting the audio features

# %%
audio_list=[]
audio_list.append(sp.audio_features(track_id)[0])
audio_list
# Out:
# [{'danceability': 0.682,
#   'energy': 0.721,
#   'key': 11,
#   'loudness': -4.256,
#   'mode': 1,
#   'speechiness': 0.0954,
#   'acousticness': 0.851,
#   'instrumentalness': 0.00684,
#   'liveness': 0.139,
#   'valence': 0.948,
#   'tempo': 81.524,
#   'type': 'audio_features',
#   'id': '3CXrCYDz7R0vm7M6HR0DTY',
#   'uri': 'spotify:track:3CXrCYDz7R0vm7M6HR0DTY',
#   'track_href': 'https://api.spotify.com/v1/tracks/3CXrCYDz7R0vm7M6HR0DTY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3CXrCYDz7R0vm7M6HR0DTY',
#   'duration_ms': 61926,
#   'time_signature': 4}]

# %%
user_song_df = pd.DataFrame(audio_list)
user_song_df
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.682   0.721   11    -4.256     1       0.0954         0.851
#
#    instrumentalness  liveness  valence   tempo            type  \
# 0           0.00684     0.139    0.948  81.524  audio_features
#
#                        id                                   uri  \
# 0  3CXrCYDz7R0vm7M6HR0DTY  spotify:track:3CXrCYDz7R0vm7M6HR0DTY
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3CXrCYDz7R0v...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3CXr...        61926
#
#    time_signature
# 0               4

# %%
user_song_df.drop(['type', 'uri'], axis=1, inplace=True)
user_song_df
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.682   0.721   11    -4.256     1       0.0954         0.851
#
#    instrumentalness  liveness  valence   tempo                      id  \
# 0           0.00684     0.139    0.948  81.524  3CXrCYDz7R0vm7M6HR0DTY
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3CXrCYDz7R0v...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3CXr...        61926
#
#    time_signature
# 0               4

# %%
user_song_df
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.682   0.721   11    -4.256     1       0.0954         0.851
#
#    instrumentalness  liveness  valence   tempo                      id  \
# 0           0.00684     0.139    0.948  81.524  3CXrCYDz7R0vm7M6HR0DTY
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3CXrCYDz7R0v...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3CXr...        61926
#
#    time_signature
# 0               4

# %%
user_input= input ("Give me a song: ")
user_input_lower= user_input.lower()
matches = difflib.get_close_matches(user_input, top_100['Title'], n=2)
if (user_input_lower in top_100['Title'].str.lower().values or len(matches)!=0):
    user_input_yes_no= input(f"Did you mean '{matches[0]}' bro ? Y or N ")
    if (user_input_yes_no=="yes"):
        random_value = top_100['Title'].sample().iloc[0]  
        print(f"You should listen to '{random_value}' on the TOP 100") 
    elif (user_input_yes_no=="no"):
        print ("Next time :)")       
else:
    print(f"'{user_input}'Not in the list but listen to this !")
    
    
    
    results_for_users= sp.search (q=user_input)
    track_id= results_for_users ["tracks"]["items"][0]["id"]

    
    
    audio_list=[]
    audio_list.append(sp.audio_features(track_id)[0])
    audio_list
    
    user_song_df = pd.DataFrame(audio_list) 
    
    print(user_song_df)
    
    user_song_df= user_song_df.drop(["analysis_url", "id", "track_href", "type", "uri"], axis=1)

    print(user_song_df)
    
    
      
    features_user_scaled = scaler.transform(user_song_df)
    features_user_scaled_df = pd.DataFrame(features_user_scaled, columns = user_song_df.columns)
    display(features_user_scaled_df)
